# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import geopandas as gpd

# %%
property_df = pd.read_parquet('../../data/raw/property_details.parquet')

# %%
# Drop rows where price = None (Sometimes not given on website)
property_df = property_df[property_df['price'].notnull()]

# Drop nbn_details, property_features columns (often left empty on website)
property_df = property_df.drop(columns=['nbn_details', 'property_features'])

# %%
property_df
# Out:
#                                                    title  \
# 0      60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1      53 Were Street, Brighton VIC 3186 - House For ...
# 2      43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3      3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4      48 Roberts Street, Frankston VIC 3199 - Studio...
# ...                                                  ...
# 14440  11 Russell Street, Darley VIC 3340 - House For...
# 14441  27 Grazing Rd, Weir Views VIC 3338 - House For...
# 14443  17 Laming Court, Mount Martha VIC 3934 - House...
# 14444  2/110 Chute Street, Mordialloc VIC 3195 - Hous...
# 14445  Carpark1209/673 Latrobe Street, Docklands VIC ...
#
#                                              description  \
# 0      View this 2 bedroom, 1 bathroom rental house a...
# 1      View this $1,500/week 4 bedroom, 2 bathroom re...
# 2      View this 3 bedroom, 2 bathroom rental townhou...
# 3      View this 5 bedroom, 2 bathroom rental house a...
# 4      View this 9 bedroom, 3 bathroom rental studio ...
# ...                                                  ...
# 14440  View this 4 bedroom, 2 bathroom rental house a...
# 14441  View this 3 bedroom, 2 bathroom rental house a...
# 14443  View this 4 bedroom, 2 bathroom rental house a...
# 14444  View this 3 bedroom, 1 bathroom rental house a...
# 14445  View this  rental house at Carpark1209/673 Lat...
#
#                                           street_address        suburb  \
# 0          60 Little Windrock Lane, Craigieburn VIC 3064   Craigieburn
# 1                      53 Were Street, Brighton VIC 3186      Brighton
# 2                   43 Tackle Drive, Point Cook VIC 3030    Point Cook
# 3               3 Rostrevor Parade, Mont Albert VIC 3127   Mont Albert
# 4                  48 Roberts Street, Frankston VIC 3199     Frankston
# ...                                                  ...           ...
# 14440                 11 Russell Street, Darley VIC 3340        Darley
# 14441                 27 Grazing Rd, Weir Views VIC 3338    Weir Views
# 14443             17 Laming Court, Mount Martha VIC 3934  Mount Martha
# 14444            2/110 Chute Street, Mordialloc VIC 3195    Mordialloc
# 14445  Carpark1209/673 Latrobe Street, Docklands VIC ...     Docklands
#
#       postcode             price  bedrooms  bathrooms  parking  \
# 0         3064     $450 Per Week       2.0        1.0      1.0
# 1         3186         $1,490.00       4.0        2.0      2.0
# 2         3030     $550 per Week       3.0        2.0      2.0
# 3         3127       $800 weekly       5.0        2.0      2.0
# 4         3199     $299 per week       9.0        3.0      4.0
# ...        ...               ...       ...        ...      ...
# 14440     3340  $530.00 per week       4.0        2.0      4.0
# 14441     3338     $415 Per Week       3.0        2.0      2.0
# 14443     3934     $700 per week       4.0        2.0      2.0
# 14444     3195     $580 per week       3.0        1.0      1.0
# 14445     3008      $46 per week       0.0        0.0      1.0
#
#       primary_property_type  \
# 0                     House
# 1                     House
# 2           Townhouse/Villa
# 3                     House
# 4                 Apartment
# ...                     ...
# 14440                 House
# 14441                 House
# 14443                 House
# 14444                 House
# 14445                 House
#
#                                      structured_features  video_count  \
# 0      [{'category': 'Indoor', 'name': 'Built in ward...          0.0
# 1                                                     []          0.0
# 2      [{'category': 'Outdoor', 'name': 'Secure Parki...          0.0
# 3                                                     []          0.0
# 4      [{'category': 'Indoor', 'name': 'Furnished', '...          0.0
# ...                                                  ...          ...
# 14440  [{'category': 'Indoor', 'name': 'Gas', 'source...          0.0
# 14441  [{'category': 'Indoor', 'name': 'Built in ward...          0.0
# 14443  [{'category': 'Outdoor', 'name': 'Secure Parki...          0.0
# 14444  [{'category': 'Indoor', 'name': 'Heating', 'so...          0.0
# 14445                                                 []          0.0
#
#        photo_count              date_listed  days_listed  floor_plans_count  \
# 0             21.0  2024-08-22T16:07:26.000         14.0                0.0
# 1              6.0  2024-06-02T18:11:41.000         95.0                2.0
# 2             17.0  2024-09-03T12:01:18.000          2.0                0.0
# 3              8.0  2024-07-01T12:53:48.000         66.0                0.0
# 4             20.0  2024-07-02T11:24:10.000         65.0                1.0
# ...            ...                      ...          ...                ...
# 14440         15.0  2024-06-26T11:09:37.000         71.0                1.0
# 14441          8.0  2024-07-26T14:51:48.000         41.0                0.0
# 14443          6.0  2024-09-02T10:21:37.000          3.0                0.0
# 14444         14.0  2024-08-12T11:27:32.000         24.0                0.0
# 14445          2.0  2022-11-29T17:45:50.000        646.0                0.0
#
#        virtual_tour                                     nearby_schools
# 0             False  [{'address': 'Craigieburn, VIC 3064', 'distanc...
# 1              True  [{'address': 'Brighton, VIC 3186', 'distance':...
# 2              True  [{'address': 'Point Cook, VIC 3030', 'distance...
# 3             False  [{'address': 'Mont Albert, VIC 3127', 'distanc...
# 4             False  [{'address': 'Frankston, VIC 3199', 'distance'...
# ...             ...                                                ...
# 14440         False  [{'address': 'Darley, VIC 3340', 'distance': 2...
# 14441         False  [{'address': 'Melton, VIC 3338', 'distance': 9...
# 14443         False  [{'address': 'Mount Martha, VIC 3934', 'distan...
# 14444         False  [{'address': 'Mordialloc, VIC 3195', 'distance...
# 14445         False  [{'address': 'West Melbourne, VIC 3006', 'dist...
#
# [11830 rows x 18 columns]

# %%
def convert_to_coord(address):
    loc = Nominatim(user_agent="property geocoder")
    getLoc = loc.geocode(address)
    if getLoc:
        return getLoc.latitude, getLoc.longitude
    else: return None

# %%
convert_to_coord('1/1-3 Sturdee Street, Reservoir, Vic 3073')
# Out:
# (-37.7007586, 145.0090779)

# %%
convert_to_coord('252 Ohallorans Road, Lara, Vic 3212')

# %%
# sub sample of 100 rows
subsample = property_df.sample(n=100)

# convert address to coordinates
subsample['coords'] = subsample.apply(lambda row: convert_to_coord(row.street_address), axis=1)

# %%
# drop rows where coords = None
subsample = subsample[subsample['coords'].notnull()]
# Out:
# title                    85
# description              85
# street_address           85
# suburb                   85
# postcode                 85
# price                    85
# bedrooms                 85
# bathrooms                85
# parking                  85
# primary_property_type    85
# structured_features      85
# video_count              85
# photo_count              85
# date_listed              85
# days_listed              85
# floor_plans_count        85
# virtual_tour             85
# nearby_schools           85
# coords                   85
# dtype: int64

# %%
from geopy.distance import distance

# find closest distance to train station
train_stations = gpd.read_file('../../data/landing/MetroTrains/PTV_METRO_TRAIN_STATION.shp')
train_stations = train_stations.to_crs('EPSG:4326')
train_stations['coords'] = train_stations.apply(lambda row: (row['LONGITUDE'], row['LATITUDE']), axis=1)

def find_closest_station(coords):
    closest_station = None
    min_distance = float('inf')
    
    for idx, row in train_stations.iterrows():
        station_coords = (row['LATITUDE'], row['LONGITUDE'])
        dist = distance(coords, station_coords).km
        
        if dist < min_distance:
            min_distance = dist
            closest_station = row['STOP_NAME']
    
    return closest_station

# %%
# find closest train station
for idx, row in subsample.iterrows():
    subsample.at[idx, 'closest_train_station'] = find_closest_station(row['coords'])
