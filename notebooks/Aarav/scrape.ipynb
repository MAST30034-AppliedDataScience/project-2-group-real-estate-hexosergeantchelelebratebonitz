# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import time

# %%
# Max 1000 property links per suburb

def get_property_links(suburb, postcode, max_pages=50):
    base_url = f'https://www.domain.com.au/rent/{suburb}-vic-{postcode}/?sort=price-desc&page='
    property_links = []

    for page in range(1, max_pages + 1):
        url = base_url + str(page)
        print(f"Getting links from page {page}...")

        response = requests.get(url, headers={'User-Agent': 'PostmanRuntime/7.6.0'})
        
        # Check if the response status code is not 200
        if response.status_code != 200:
            print(f"Failed to retrieve page {page}. Status code: {response.status_code}. Exiting loop.")
            break
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        listings = soup.find_all('a', class_='address')

        if not listings:
            print(f"No listings found on page {page}. Exiting loop.")
            break

        for listing in listings:
            link = listing.get('href')
            if link:
                property_links.append(link)
    
    return property_links

# %%
suburb = 'essendon'
postcode = '3040'

property_links = get_property_links(suburb, postcode)
# Out:
# Getting links from page 1...
# Getting links from page 2...
# Getting links from page 3...
# Getting links from page 4...
# Getting links from page 5...
# Getting links from page 6...
# Getting links from page 7...
# Getting links from page 8...
# Getting links from page 9...
# Getting links from page 10...
# Getting links from page 11...
# Getting links from page 12...
# Getting links from page 13...
# Getting links from page 14...
# Getting links from page 15...
# Getting links from page 16...
# Getting links from page 17...
# No listings found on page 17. Exiting loop.

# %%
# Convert to DataFrame and save to CSV
df = pd.DataFrame(property_links, columns=['Property Link'])

# %%
import json

def extract_json_data(soup):
    # Look for any script tags that might contain JSON data
    for script in soup.find_all('script'):
        if script.string and 'application/json' in script.attrs.get('type', ''):
            try:
                json_data = json.loads(script.string)
                return json_data
            except json.JSONDecodeError:
                continue
    return None

# %%
def extract_property_details(soup):
    # Locate the JSON data embedded in the HTML
    script_data = soup.find('script', id='__NEXT_DATA__').string
    json_data = json.loads(script_data)
    
    # Extract necessary details
    layout_props = json_data['props']['pageProps']['layoutProps']
    property_details = layout_props["digitalData"]["page"]["pageInfo"]["property"]
    component_props = json_data['props']['pageProps']['componentProps']
    
    data = {
        'title': layout_props.get('title'),
        'description': layout_props.get('description'),
        'street_adress': property_details.get('address'),
        'suburb': property_details.get('suburb'),
        'postcode': property_details.get('postcode'),
        'price': property_details.get('price'),
        'bedrooms': property_details.get('bedrooms'),
        'bathrooms': property_details.get('bathrooms'),
        'parking': property_details.get('parking'),
        'primary_property_type': property_details.get('primaryPropertyType'),
        'property_features': property_details.get('propertyFeatures'),
        'structured_features': property_details.get('structuredFeatures', []),
        'video_count': property_details.get('videoCount'),
        'photo_count': property_details.get('photoCount'),
        'date_listed': property_details.get('dateListed'),
        'days_listed': property_details.get('daysListed'),
        'floor_plans_count': property_details.get('floorPlansCount'),
        'virtual_tour': property_details.get('virtualTour'),
        'nbn_details': layout_props.get('nbnDetails'),
        'nearby_schools': component_props.get('schoolCatchment', {}).get('schools', [])
    }
    
    return data

# %%
def scrape_properties(property_links):
    # Create an empty list to store the property details
    all_properties = []

    for url in property_links:
        # Fetch the page content
        soup = BeautifulSoup(requests.get(url, headers={'User-Agent':"PostmanRuntime/7.6.0"}).content, 'html.parser')
        
        # Extract the property details
        property_data = extract_property_details(soup)
        all_properties.append(property_data)
    
    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(all_properties)
    return df

# %%
property_df = scrape_properties(property_links)

# %%
property_df.to_csv(f'property_details.csv', index=False)

# %%
property_df
# Out:
#                                                  title  \
# 0    12 Riverview Road, Essendon VIC 3040 - House F...
# 1    28 Violet Street, Essendon VIC 3040 - Apartmen...
# 2    81 Deakin Street, Essendon VIC 3040 - Townhous...
# 3    1/20 Fletcher St, Essendon VIC 3040 - Townhous...
# 4    10 Butler Street, Essendon VIC 3040 - House Fo...
# ..                                                 ...
# 305  15/3 Royal Ave, Essendon North VIC 3041 - Stud...
# 306  2/49 Bent Street, Moonee Ponds VIC 3039 - Apar...
# 307  5/140 Maribyrnong Road, Moonee Ponds VIC 3039 ...
# 308  5/26 Collier Crescent, Brunswick West VIC 3055...
# 309  50 Combermere St, Aberfeldie VIC 3040 - Apartm...
#
#                                            description  \
# 0    View this 5 bedroom, 2 bathroom rental house a...
# 1    View this 3 bedroom, 2 bathroom rental apartme...
# 2    View this $950/week 4 bedroom, 3 bathroom rent...
# 3    View this $920/week 4 bedroom, 3 bathroom rent...
# 4    View this 4 bedroom, 2 bathroom rental house a...
# ..                                                 ...
# 305  View this 1 bedroom, 1 bathroom rental studio ...
# 306  View this 1 bedroom, 1 bathroom rental apartme...
# 307  View this $310/week 1 bedroom, 1 bathroom rent...
# 308  View this 1 bedroom, 1 bathroom rental studio ...
# 309  View this 1 bedroom, 1 bathroom rental apartme...
#
#                                       street_adress          suburb postcode  \
# 0              12 Riverview Road, Essendon VIC 3040        Essendon     3040
# 1               28 Violet Street, Essendon VIC 3040        Essendon     3040
# 2               81 Deakin Street, Essendon VIC 3040        Essendon     3040
# 3               1/20 Fletcher St, Essendon VIC 3040        Essendon     3040
# 4               10 Butler Street, Essendon VIC 3040        Essendon     3040
# ..                                              ...             ...      ...
# 305         15/3 Royal Ave, Essendon North VIC 3041  Essendon North     3041
# 306         2/49 Bent Street, Moonee Ponds VIC 3039    Moonee Ponds     3039
# 307   5/140 Maribyrnong Road, Moonee Ponds VIC 3039    Moonee Ponds     3039
# 308  5/26 Collier Crescent, Brunswick West VIC 3055  Brunswick West     3055
# 309           50 Combermere St, Aberfeldie VIC 3040      Aberfeldie     3040
#
#                   price  bedrooms  bathrooms  parking primary_property_type  \
# 0    $2280pw / $9907pcm         5          2        4                 House
# 1         $950 per week         3          2        3             Apartment
# 2               $950.00         4          3        2       Townhouse/Villa
# 3               $920.00         4          3        2       Townhouse/Villa
# 4     $900pw / $3910pcm         4          2        2                 House
# ..                  ...       ...        ...      ...                   ...
# 305         $310 weekly         1          1        1             Apartment
# 306       $310 Per Week         1          1        2             Apartment
# 307             $310.00         1          1        1             Apartment
# 308         $320 Weekly         1          1        1             Apartment
# 309         $295 weekly         1          1        0             Apartment
#
#                                      property_features  \
# 0                                     Air conditioning
# 1                                                 None
# 2    Secure Parking, Air conditioning, Alarm System...
# 3    Secure Parking, Air conditioning, Balcony / De...
# 4    Air conditioning, Ducted Cooling, Ducted Heati...
# ..                                                 ...
# 305  Secure Parking, Built in wardrobes, Floorboard...
# 306                                               None
# 307                                               None
# 308                                 Built in wardrobes
# 309      Air conditioning, Secure Parking, Floorboards
#
#                                    structured_features  video_count  \
# 0    [{'name': 'Gas', 'category': 'Indoor', 'source...            0
# 1    [{'name': 'Secure Parking', 'category': 'Outdo...            0
# 2    [{'name': 'Internal Laundry', 'category': 'Ind...            0
# 3    [{'name': 'Internal Laundry', 'category': 'Ind...            0
# 4    [{'name': 'Internal Laundry', 'category': 'Ind...            0
# ..                                                 ...          ...
# 305  [{'name': 'Heating', 'category': 'Indoor', 'so...            0
# 306                                                 []            0
# 307  [{'name': 'Heating', 'category': 'Indoor', 'so...            0
# 308  [{'name': 'Internal Laundry', 'category': 'Ind...            1
# 309  [{'name': 'Internal Laundry', 'category': 'Ind...            0
#
#      photo_count              date_listed  days_listed  floor_plans_count  \
# 0             13  2024-08-05T10:21:05.000           29                  0
# 1              5  2024-09-02T16:36:08.000            1                  0
# 2              5  2024-08-30T16:01:05.000            4                  0
# 3             14  2024-07-23T11:59:13.000           42                  1
# 4             16  2024-07-23T15:05:33.000           42                  0
# ..           ...                      ...          ...                ...
# 305            7  2024-08-08T10:22:39.000           26                  0
# 306            5  2024-03-15T10:41:03.000          172                  0
# 307            5  2024-08-29T10:26:32.000            5                  0
# 308            4  2024-08-12T13:20:55.000           22                  0
# 309            6  2024-08-23T12:35:46.000           11                  0
#
#      virtual_tour nbn_details  \
# 0           False        None
# 1           False        None
# 2           False        None
# 3           False        None
# 4           False        None
# ..            ...         ...
# 305         False        None
# 306         False        None
# 307         False        None
# 308         False        None
# 309         False        None
#
#                                         nearby_schools
# 0    [{'id': '', 'educationLevel': 'combined', 'nam...
# 1    [{'id': '', 'educationLevel': 'secondary', 'na...
# 2    [{'id': '2139', 'educationLevel': 'primary', '...
# 3    [{'id': '1638', 'educationLevel': 'primary', '...
# 4    [{'id': '2132', 'educationLevel': 'primary', '...
# ..                                                 ...
# 305  [{'id': '1637', 'educationLevel': 'primary', '...
# 306  [{'id': '2821', 'educationLevel': 'primary', '...
# 307  [{'id': '10491', 'educationLevel': 'primary', ...
# 308  [{'id': '1183', 'educationLevel': 'primary', '...
# 309  [{'id': '', 'educationLevel': 'secondary', 'na...
#
# [310 rows x 20 columns]
