# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the shapefile
shapefile_path = "../../data/landing/GDA2020/vic_localities.shp"  # Replace with your shapefile path
gdf = gpd.read_file(shapefile_path)

# View the first few rows of the data
print(gdf.head())

# Plot the shapefile to see a rough map
gdf.plot()

# Show the plot
plt.show()
# Out:
#         LC_PLY_PID          LOC_PID   DT_CREATE    LOC_NAME  \
# 0  lcp-ejVyte1DxXx  locb0dcb52a6b55  2023-06-26    Abbeyard
# 1  lcp386f2bcf9bce  locb9872f35df41  2021-06-24  Abbotsford
# 2  lcprFRP2-cPMfr5  loc8123ed12ea8d  2023-03-21  Aberfeldie
# 3  lcpj3KHi-vakgFj  loc1eb4a229104a  2023-12-10   Aberfeldy
# 4  lcpoO-hq-yZZASg  locb17be87767e1  2023-12-10     Acheron
#
#            LOC_CLASS STATE                                           geometry
# 0  Gazetted Locality   VIC  POLYGON ((146.65061 -36.94496, 146.68449 -36.9...
# 1  Gazetted Locality   VIC  POLYGON ((144.99137 -37.80959, 144.99254 -37.8...
# 2  Gazetted Locality   VIC  POLYGON ((144.88854 -37.75546, 144.88854 -37.7...
# 3  Gazetted Locality   VIC  POLYGON ((146.35535 -37.69944, 146.35751 -37.6...
# 4  Gazetted Locality   VIC  POLYGON ((145.638 -37.28417, 145.64233 -37.279...

# %%
gdf
# Out:
#            LC_PLY_PID          LOC_PID   DT_CREATE    LOC_NAME  \
# 0     lcp-ejVyte1DxXx  locb0dcb52a6b55  2023-06-26    Abbeyard
# 1     lcp386f2bcf9bce  locb9872f35df41  2021-06-24  Abbotsford
# 2     lcprFRP2-cPMfr5  loc8123ed12ea8d  2023-03-21  Aberfeldie
# 3     lcpj3KHi-vakgFj  loc1eb4a229104a  2023-12-10   Aberfeldy
# 4     lcpoO-hq-yZZASg  locb17be87767e1  2023-12-10     Acheron
# ...               ...              ...         ...         ...
# 2968  lcpen8klpgj0ZHd  loc81a970cc91ee  2024-03-19     Yundool
# 2969  lcp8d12ab6daadf  loc974441b38fa0  2021-06-24      Yuroke
# 2970  lcp1NsdmW0lG6PP  locffa8d48503ab  2023-12-10     Yuulong
# 2971  lcpMajb8Sk2dyrp  locadbdb687a089  2024-03-19     Zeerust
# 2972  lcp1D08zaOEsvc1  locf9eae74772b7  2024-06-16   Zumsteins
#
#               LOC_CLASS STATE  \
# 0     Gazetted Locality   VIC
# 1     Gazetted Locality   VIC
# 2     Gazetted Locality   VIC
# 3     Gazetted Locality   VIC
# 4     Gazetted Locality   VIC
# ...                 ...   ...
# 2968  Gazetted Locality   VIC
# 2969  Gazetted Locality   VIC
# 2970  Gazetted Locality   VIC
# 2971  Gazetted Locality   VIC
# 2972  Gazetted Locality   VIC
#
#                                                geometry
# 0     POLYGON ((146.65061 -36.94496, 146.68449 -36.9...
# 1     POLYGON ((144.99137 -37.80959, 144.99254 -37.8...
# 2     POLYGON ((144.88854 -37.75546, 144.88854 -37.7...
# 3     POLYGON ((146.35535 -37.69944, 146.35751 -37.6...
# 4     POLYGON ((145.638 -37.28417, 145.64233 -37.279...
# ...                                                 ...
# 2968  POLYGON ((145.77616 -36.25349, 145.79181 -36.2...
# 2969  POLYGON ((144.84397 -37.5857, 144.84547 -37.57...
# 2970  POLYGON ((143.25058 -38.72729, 143.25059 -38.7...
# 2971  POLYGON ((145.36826 -36.25123, 145.36831 -36.2...
# 2972  POLYGON ((142.25242 -37.14996, 142.25573 -37.1...
#
# [2973 rows x 7 columns]
