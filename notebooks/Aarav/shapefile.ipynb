# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the shapefile
shapefile_path = "../../data/landing/GDA2020/vic_localities.shp"  # Replace with your shapefile path
gdf = gpd.read_file(shapefile_path)

# View the first few rows of the data
print(gdf.head())

# Plot the shapefile to see a rough map
gdf.plot()

# Show the plot
plt.show()
# Out:
#         LC_PLY_PID          LOC_PID  DT_CREATE    LOC_NAME          LOC_CLASS  \
# 0  lcp-ejVyte1DxXx  locb0dcb52a6b55 2023-06-26    Abbeyard  Gazetted Locality
# 1  lcp386f2bcf9bce  locb9872f35df41 2021-06-24  Abbotsford  Gazetted Locality
# 2  lcprFRP2-cPMfr5  loc8123ed12ea8d 2023-03-21  Aberfeldie  Gazetted Locality
# 3  lcpj3KHi-vakgFj  loc1eb4a229104a 2023-12-10   Aberfeldy  Gazetted Locality
# 4  lcpoO-hq-yZZASg  locb17be87767e1 2023-12-10     Acheron  Gazetted Locality
#
#   STATE                                           geometry
# 0   VIC  POLYGON ((146.65061 -36.94496, 146.68449 -36.9...
# 1   VIC  POLYGON ((144.99137 -37.80959, 144.99254 -37.8...
# 2   VIC  POLYGON ((144.88854 -37.75546, 144.88854 -37.7...
# 3   VIC  POLYGON ((146.35535 -37.69944, 146.35751 -37.6...
# 4   VIC  POLYGON ((145.638 -37.28417, 145.64233 -37.279...

# %%
# Find loc_class = abbotsford
gdf_abbotsford = gdf[gdf["LOC_NAME"] == "Abbotsford"]

gdf_abbotsford
# Out:
#            LC_PLY_PID          LOC_PID  DT_CREATE LOC_NAME          LOC_CLASS  \
# 2274  lcpvxidnZ2BgGtK  loce01794437106 2023-06-26   Seddon  Gazetted Locality
#
#      STATE                                           geometry
# 2274   VIC  POLYGON ((144.88417 -37.8092, 144.88528 -37.80...
