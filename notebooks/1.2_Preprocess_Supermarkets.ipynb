# %% [markdown]
# # Supermarkets using Overpass API

# %%
import requests
import pandas as pd

# %%
# Define the Overpass API URL
overpass_url = "http://overpass-api.de/api/interpreter"

# %%
# Overpass API query to find all supermarkets in Victoria
overpass_query = """
[out:json];
area["name"="Victoria"]->.searchArea;
node["shop"="supermarket"](area.searchArea);
out body;
"""

# %%
# Make the API request
response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

# %%
response
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.1 084b4234',
#  'osm3s': {'timestamp_osm_base': '2024-09-15T14:18:00Z',
#   'timestamp_areas_base': '2024-09-15T08:49:43Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 32193447,
#    'lat': -37.2773622,
#    'lon': 144.7338613,
#    'tags': {'name': 'IGA', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 218028470,
#    'lat': -37.7914336,
#    'lon': 145.1718422,
#    'tags': {'addr:housenumber': '55',
#     'addr:street': 'Tunstall Square',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': '07:00-24:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'postal_code': '3109',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 222420863,
#    'lat': -37.7889872,
#    'lon': 144.9760904,
#    'tags': {'addr:housenumber': '799',
#     'addr:street': 'Nicholson Street',
#     'branch': 'Carlton North',
#     'brand': 'Foodworks',
#     'brand:wikidata': 'Q5465579',
#     'brand:wikipedia': 'en:FoodWorks',
#     'fixme': 'Is this still open?',
#     'name': 'Foodworks',
#     'opening_hours': '24/7',
#     'phone': '+61 3 9380 1648',
#     'shop': 'supermarket',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 247822855,
#    'lat': 48.4379459,
#    'lon': -123.3124029,
#    'tags': {'addr:street': 'Cadboro Bay Road',
#     'name': 'The Old Farm Market',
#     'opening_hours': 'Mo-Su 07:00-19:00',
#     'shop': 'supermarket',
#     'website': 'https://theoldfarmmarket.ca'}},
#   {'type': 'node',
#    'id': 258471456,
#    'lat': -37.8547864,
#    'lon': 145.1826504,
#    'tags': {'addr:housenumber': '495-511',
#     'addr:street': 'Burwood Highway',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'building': 'yes',
#     'full_name': 'Coles Vermont South',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 260559651,
#    'lat': -37.8682575,
#    'lon': 145.240404,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 260710477,
#    'lat': -37.83496,
#    'lon': 145.1643348,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 260710501,
#    'lat': -37.8358294,
#    'lon': 145.1644531,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 278111955,
#    'lat': -38.3614651,
#    'lon': 144.8921554,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 278926518,
#    'lat': -37.794199,
#    'lon': 145.2791738,
#    'tags': {'addr:housenumber': '5-15',
#     'addr:postcode': '3136',
#     'addr:state': 'VIC',
#     'addr:street': 'Kent Avenue',
#     'addr:suburb': 'Croydon',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 7004 7700',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 279408382,
#    'lat': 48.4448869,
#    'lon': -123.338159,
#    'tags': {'addr:housenumber': '1580',
#     'addr:postcode': 'V8T 4Y3',
#     'addr:street': 'Hillside Avenue',
#     'name': 'Thrifty Foods',
#     'not:brand:wikidata': 'Q1143340',
#     'opening_hours': '06:00-24:00',
#     'operator': 'Thrifty Foods',
#     'phone': '+1-250-370-9591',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 279739124,
#    'lat': -36.7508127,
#    'lon': 145.5710032,
#    'tags': {'addr:city': 'Euroa',
#     'addr:housenumber': '75',
#     'addr:postcode': '3666',
#     'addr:state': 'VIC',
#     'addr:street': 'Binney Street',
#     'addr:suburb': 'Euroa',
#     'branch': 'Burtons SUPA IGA',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Fr 08:30-18:00; Sa 08:30-12:30; Su 09:00-13:00',
#     'operator': 'IGA',
#     'phone': '+61 3 5795 2004',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/'}},
#   {'type': 'node',
#    'id': 280708140,
#    'lat': -37.9208945,
#    'lon': 145.2375525,
#    'tags': {'addr:housenumber': '1101',
#     'addr:street': 'Stud Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 280897051,
#    'lat': -37.8855399,
#    'lon': 145.0845484,
#    'tags': {'branch': 'Chadstone',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 280897094,
#    'lat': -37.887188,
#    'lon': 145.0842821,
#    'tags': {'addr:housenumber': '1341',
#     'addr:street': 'Dandenong Road',
#     'alt_name': 'Woolworths Chadstone;Chadstone Woolworths',
#     'branch': 'Chadstone',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'check_date': '2023-04-13',
#     'name': 'Woolworths',
#     'opening_hours': 'closed; "Temporarily closed"',
#     'operator': 'Woolworths Group',
#     'operator:ref:abn': '88000014675',
#     'operator:wikidata': 'Q607272',
#     'phone': '+61 3 8347 6545',
#     'ref': '3335',
#     'shop': 'supermarket',
#     'toilets': 'no',
#     'website': 'https://www.woolworths.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 280897102,
#    'lat': -37.8863767,
#    'lon': 145.0839366,
#    'tags': {'addr:housenumber': '1341',
#     'addr:street': 'Dandenong Road',
#     'alt_name': 'Aldi Chadstone;Chadstone Aldi',
#     'branch': 'Chadstone',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q125054',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date': '2023-04-13',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Chadstone',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'operator:ref:abn': '90196565019',
#     'shop': 'supermarket',
#     'toilets': 'no',
#     'website': 'https://store.aldi.com.au/vic/chadstone/1341-dandenong-road',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 282619702,
#    'lat': 48.4609521,
#    'lon': -123.296921,
#    'tags': {'addr:city': 'Victoria',
#     'addr:housenumber': '3829',
#     'addr:postcode': 'V8N 4G1',
#     'addr:province': 'BC',
#     'addr:street': 'Cadboro Bay Road',
#     'name': "Pepper's Foods",
#     'phone': '+12504778513',
#     'shop': 'supermarket',
#     'source': 'Survey',
#     'website': 'https://peppers-foods.com/'}},
#   {'type': 'node',
#    'id': 290313333,
#    'lat': -37.8747789,
#    'lon': 144.6794291,
#    'tags': {'addr:housenumber': '250',
#     'addr:street': 'Heaths Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 302129542,
#    'lat': -37.7981407,
#    'lon': 144.9683576,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 314087330,
#    'lat': -37.8535375,
#    'lon': 145.1487011,
#    'tags': {'addr:housenumber': '172-210',
#     'addr:street': 'Burwood Highway',
#     'branch': 'Burwood East',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'check_date': '2023-10-28',
#     'full_name': 'Coles East Burwood',
#     'name': 'Coles',
#     'opening_hours': '24/7',
#     'operator': 'Coles Supermarkets Australia Pty Ltd',
#     'operator:ref:abn': '45004189708',
#     'phone': '+61 3 9847 8300',
#     'ref': '584',
#     'shop': 'supermarket',
#     'source': 'survey',
#     'website': 'https://www.coles.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 317338900,
#    'lat': -37.8943767,
#    'lon': 145.3080703,
#    'tags': {'addr:housenumber': '1202',
#     'addr:street': 'Burwood Highway',
#     'name': 'Maxi Foods',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'phone': '+61 3 9752 4299',
#     'shop': 'supermarket',
#     'website': 'https://www.lemaxgroup.com.au/upper-ferntree-gully'}},
#   {'type': 'node',
#    'id': 317697330,
#    'lat': -37.949435,
#    'lon': 145.0033564,
#    'tags': {'addr:housenumber': '10-20',
#     'addr:street': 'Waltham Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 319601982,
#    'lat': -37.8747173,
#    'lon': 145.1648652,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'level': '1',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 319602021,
#    'lat': -37.8768747,
#    'lon': 145.1645918,
#    'tags': {'addr:housenumber': '227-235',
#     'addr:street': 'Springvale Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'level': '1',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 320839137,
#    'lat': -37.8229337,
#    'lon': 145.3020376,
#    'tags': {'addr:housenumber': '17-39',
#     'addr:postcode': '3153',
#     'addr:state': 'VIC',
#     'addr:street': 'Canterbury Road',
#     'addr:suburb': 'Bayswater North',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 06:00-00:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'phone': '+61 3 8756 2407',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 323466241,
#    'lat': -37.803235,
#    'lon': 145.3108152,
#    'tags': {'addr:housenumber': '534-542',
#     'addr:postcode': '3137',
#     'addr:state': 'VIC',
#     'addr:street': 'Mount Dandenong Road',
#     'addr:suburb': 'Kilysth',
#     'addr:unit': '1',
#     'branch': 'Kilsyth',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'phone': '+61 3 8756 2437',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/shop/storelocator/vic-kilsyth-3369'}},
#   {'type': 'node',
#    'id': 324207736,
#    'lat': -37.9097755,
#    'lon': 145.1898734,
#    'tags': {'branch': 'Wheelers Hill',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 325276531,
#    'lat': -37.6856825,
#    'lon': 144.5657612,
#    'tags': {'addr:housenumber': '533-555',
#     'addr:street': 'High Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 325276537,
#    'lat': -37.6855804,
#    'lon': 144.5669149,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 328419988,
#    'lat': -37.7597746,
#    'lon': 145.0007011,
#    'tags': {'created_by': 'Potlatch 0.10f',
#     'name': 'Psarakos Market',
#     'opening_hours': 'Mo-Fr 09:00-18:00; Sa 08:00-16:00; PH,Su off',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 335617280,
#    'lat': -37.8612829,
#    'lon': 145.2875436,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 338731049,
#    'lat': 48.4263755,
#    'lon': -123.3164599,
#    'tags': {'addr:housenumber': '2187',
#     'addr:postcode': 'V8R 1G1',
#     'addr:street': 'Oak Bay Avenue',
#     'addr:unit': '101',
#     'name': 'Fairway Market Athlone Court',
#     'opening_hours': '08:00-22:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 338906162,
#    'lat': -37.7601449,
#    'lon': 145.3494123,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 355763256,
#    'lat': -37.8784183,
#    'lon': 145.1276618,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 355763558,
#    'lat': -37.8763513,
#    'lon': 145.1285091,
#    'tags': {'name': "Ritchie's IGA",
#     'operator': 'IGA',
#     'payment:cash': 'yes',
#     'payment:coins': 'yes',
#     'payment:credit_cards': 'yes',
#     'shop': 'supermarket',
#     'website': 'http://www.iga.net.au'}},
#   {'type': 'node',
#    'id': 360214093,
#    'lat': -38.0778107,
#    'lon': 145.4790259,
#    'tags': {'addr:housenumber': '67-69',
#     'addr:street': 'Main Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 360214350,
#    'lat': -38.0791372,
#    'lon': 145.4828066,
#    'tags': {'brand': 'Ritchies',
#     'brand:wikidata': 'Q7336696',
#     'brand:wikipedia': 'en:Ritchies Stores',
#     'name': 'Ritchies',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 364632405,
#    'lat': -38.0816497,
#    'lon': 145.2782581,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'contact:website': 'http://www.woolworths.com.au',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 364658541,
#    'lat': -38.0857063,
#    'lon': 145.4709464,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 365210758,
#    'lat': -38.115432,
#    'lon': 145.1930495,
#    'tags': {'addr:housenumber': '335',
#     'addr:street': 'Ballarto Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 365210772,
#    'lat': -38.140202,
#    'lon': 145.126413,
#    'tags': {'addr:suburb': 'Frankston',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 365210773,
#    'lat': -38.1421829,
#    'lon': 145.1234117,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 365211158,
#    'lat': -37.9834708,
#    'lon': 145.1329898,
#    'tags': {'addr:housenumber': '89',
#     'addr:street': 'Centre Dandenong Road',
#     'addr:suburb': 'Dingley Village',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 365211574,
#    'lat': -37.9590509,
#    'lon': 145.0548965,
#    'tags': {'addr:housenumber': '1239',
#     'addr:street': 'Nepean Highway',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Southland',
#     'level': '0',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Fr 08:30-20:00; Sa-Su 08:30-19:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/southland/1239-nepean-highway',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 365211575,
#    'lat': -37.9589132,
#    'lon': 145.0512356,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'level': '0',
#     'level:ref': '1',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 9239 6100',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 367127064,
#    'lat': -38.2193814,
#    'lon': 145.0401252,
#    'tags': {'addr:housenumber': '78',
#     'addr:street': 'Barkly Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 367127279,
#    'lat': -38.1838062,
#    'lon': 145.0898802,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'check_date:opening_hours': '2022-09-16',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 368387444,
#    'lat': -38.2244567,
#    'lon': 145.1715701,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 368387447,
#    'lat': -38.2240036,
#    'lon': 145.1703702,
#    'tags': {'addr:housenumber': '49',
#     'addr:street': 'Eramosa Road West',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 369690027,
#    'lat': -37.9828511,
#    'lon': 145.2136939,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 06:00-24:00',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 370224122,
#    'lat': -37.798856,
#    'lon': 144.953525,
#    'tags': {'addr:housenumber': '75',
#     'addr:street': 'Flemington Road',
#     'name': 'North Melbourne IGA X-press',
#     'phone': '+61 3 9328 8800',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 371340938,
#    'lat': -38.1122489,
#    'lon': 145.1566421,
#    'tags': {'addr:housenumber': '280',
#     'addr:street': 'Seaford Road',
#     'brand': 'Ritchies',
#     'brand:wikidata': 'Q7336696',
#     'brand:wikipedia': 'en:Ritchies Stores',
#     'name': 'Ritchies IGA',
#     'opening_hours': 'Mo-Fr 08:00-22:00,Sa-Su 08:00-21:00',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'phone': '+61 3 9786 2716',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 411155008,
#    'lat': -38.6059357,
#    'lon': 145.5890138,
#    'tags': {'branch': 'Wonthaggi',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (Australian supermarket group)',
#     'check_date': '2023-10-31',
#     'name': 'IGA',
#     'official_name': 'Ritchies Supa IGA',
#     'opening_hours': 'Mo-Sa 08:00-21:00; Su 08:30-18:00',
#     'operator': 'Ritchies Stores Pty Ltd',
#     'operator:ref:abn': '61005041814',
#     'phone': '+61 3 5672 1277',
#     'shop': 'supermarket',
#     'source': 'survey',
#     'website': 'https://www.iga.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 411155013,
#    'lat': -38.6042866,
#    'lon': 145.5926656,
#    'tags': {'alt_name': 'Wonthaggi Aldi; Aldi Wonthaggi',
#     'branch': 'Wonthaggi',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'changing_table': 'no',
#     'check_date': '2023-02-11',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Wonthaggi',
#     'internet_access': 'no',
#     'kids_area': 'no',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'operator:ref:abn': '90196565019',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'shop': 'supermarket',
#     'toilets': 'no',
#     'website': 'https://store.aldi.com.au/vic/wonthaggi/cnr-murray-street-mckenzie-street',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 427864919,
#    'lat': -37.9929941,
#    'lon': 145.172621,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 427864933,
#    'lat': -37.9922837,
#    'lon': 145.1719538,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 441991395,
#    'lat': -37.8254909,
#    'lon': 144.9947938,
#    'tags': {'addr:housenumber': '150',
#     'addr:street': 'Swan Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 06:00-00:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 9420 3000',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 442872640,
#    'lat': -37.8821985,
#    'lon': 145.2944036,
#    'tags': {'addr:housenumber': '107',
#     'addr:street': 'Station Street',
#     'addr:unit': '3',
#     'branch': 'Ferntree Gully',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (Australian supermarket group)',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Th 07:30-19:00; Fr 07:30-20:00; Sa, Su 08:00-19:00',
#     'phone': '+61 3 9752 3999',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au'}},
#   {'type': 'node',
#    'id': 449383332,
#    'lat': -37.8845285,
#    'lon': 145.0587077,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 457388148,
#    'lat': -37.4614389,
#    'lon': 147.2508422,
#    'tags': {'name': 'Dargo General Store', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 461534089,
#    'lat': -37.8952497,
#    'lon': 144.7530363,
#    'tags': {'addr:housenumber': '300',
#     'addr:street': 'Point Cook Road',
#     'branch': 'Sanctuary Lakes',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 06:00-24:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 465186430,
#    'lat': -37.7869266,
#    'lon': 145.1257942,
#    'tags': {'addr:housenumber': '619',
#     'addr:street': 'Doncaster Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 465186446,
#    'lat': -37.7869012,
#    'lon': 145.1264487,
#    'tags': {'branch': 'Doncaster',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 466999648,
#    'lat': 48.4139119,
#    'lon': -123.356505,
#    'tags': {'addr:city': 'Victoria',
#     'addr:housenumber': '271',
#     'addr:postcode': 'V8V 3X4',
#     'addr:province': 'BC',
#     'addr:street': 'Cook Street',
#     'name': 'The Root Cellar Village Green Grocer',
#     'opening_hours': 'Mo-Su 08:00-20:00',
#     'phone': '+1 778-265-8166',
#     'shop': 'supermarket',
#     'website': 'https://www.therootcellar.ca/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 469459628,
#    'lat': -37.8628805,
#    'lon': 145.0271098,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 473363977,
#    'lat': -37.7070041,
#    'lon': 144.9387874,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 480460754,
#    'lat': -38.0686164,
#    'lon': 145.3007558,
#    'tags': {'addr:housenumber': '400',
#     'addr:street': 'Cranbourne Road',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 489359440,
#    'lat': -37.029562,
#    'lon': 145.1463322,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (Australian supermarket group)',
#     'name': 'IGA',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 489379485,
#    'lat': -38.3138184,
#    'lon': 146.4201968,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 489384726,
#    'lat': -38.3121751,
#    'lon': 146.4210208,
#    'tags': {'name': 'Richies IGA Churchill', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 492158855,
#    'lat': 14.2073344,
#    'lon': 121.3496857,
#    'tags': {'addr:city': 'Victoria',
#     'addr:postcode': '4011',
#     'addr:street': 'National Highway',
#     'name': 'South Emerald Supermarket',
#     'old_name': 'M & W Townstore',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 492900388,
#    'lat': -37.6508313,
#    'lon': 145.0687423,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 492905311,
#    'lat': -37.6520545,
#    'lon': 145.0741496,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 493149747,
#    'lat': -36.3882462,
#    'lon': 145.4245579,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 506153647,
#    'lat': -37.8205606,
#    'lon': 144.9436054,
#    'tags': {'branch': 'Victoria Harbour',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'diet:halal': 'yes',
#     'diet:kosher': 'yes',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Fr 07:00-23:00; Sa,Su 08:00-23:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.woolworths.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 508030778,
#    'lat': -37.7930599,
#    'lon': 144.8607906,
#    'tags': {'addr:housenumber': '67',
#     'addr:street': 'Ashley Street',
#     'brand': 'Aldi',
#     'brand:wikidata': 'Q125054',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI West Footscray',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/west-footscray/67-ashley-street',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 508030779,
#    'lat': -37.7936568,
#    'lon': 144.8603614,
#    'tags': {'addr:housenumber': '67',
#     'addr:street': 'Ashley Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 515973782,
#    'lat': -38.1620606,
#    'lon': 145.9324454,
#    'tags': {'addr:housenumber': '30-36',
#     'addr:street': 'Palmerston Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 06:00-24:00',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 515973822,
#    'lat': -38.1600589,
#    'lon': 145.9306082,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'check_date': '2024-08-27',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 531399027,
#    'lat': -37.7151557,
#    'lon': 145.1486437,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 531399725,
#    'lat': -37.7128407,
#    'lon': 145.1501999,
#    'tags': {'addr:housenumber': '6-20',
#     'addr:street': 'Luck Street',
#     'brand': 'Aldi',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Eltham',
#     'name': 'Aldi',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/eltham/6-20-luck-street'}},
#   {'type': 'node',
#    'id': 532731485,
#    'lat': -37.8779529,
#    'lon': 147.9944713,
#    'tags': {'brand': 'Foodworks',
#     'brand:wikidata': 'Q5465579',
#     'brand:wikipedia': 'en:FoodWorks',
#     'name': 'Foodworks',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 538205612,
#    'lat': -37.7126927,
#    'lon': 145.0925869,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q3146662',
#     'brand:wikipedia': 'en:IGA (supermarkets)',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Fr 08:00-20:00 , Sa-Su 08:00-17:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 538206163,
#    'lat': -37.70242,
#    'lon': 145.1028078,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'level': '1',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 541326972,
#    'lat': -37.0520648,
#    'lon': 146.0901564,
#    'tags': {'addr:housenumber': '47',
#     'addr:postcode': '3722',
#     'addr:state': 'VIC',
#     'addr:street': 'High Street',
#     'addr:suburb': 'Mansfield',
#     'branch': 'Marks SUPA IGA Mansfield',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Su 08:00-20:00',
#     'phone': '+61 3 5775 2014',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 552752115,
#    'lat': -37.7971249,
#    'lon': 145.2569815,
#    'tags': {'addr:housenumber': '434',
#     'addr:postcode': '3136',
#     'addr:state': 'VIC',
#     'addr:street': 'Maroondah Highway',
#     'addr:suburb': 'Croydon',
#     'branch': 'Burntbridge',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 07:00-21:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 9870 6334',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 563701491,
#    'lat': -37.4133779,
#    'lon': 144.9783977,
#    'tags': {'addr:housenumber': '69-79',
#     'addr:street': 'High Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'full_name': 'Coles Wallan',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 5783 3233',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 563705087,
#    'lat': -37.4113849,
#    'lon': 144.9784229,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'full_name': 'Woolworths Wallan',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 565827592,
#    'lat': -37.8155086,
#    'lon': 145.2212725,
#    'tags': {'addr:housenumber': '59',
#     'addr:postcode': '3134',
#     'addr:state': 'VIC',
#     'addr:street': 'Maroondah Highway',
#     'addr:suburb': 'Ringwood',
#     'branch': 'Ringwood',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 7004 3800',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 565827593,
#    'lat': -37.815856,
#    'lon': 145.2231415,
#    'tags': {'addr:postcode': '3134',
#     'addr:state': 'VIC',
#     'addr:suburb': 'Ringwood',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Ringwood',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/ringwood/cnr-maroondah-highway-new-street'}},
#   {'type': 'node',
#    'id': 566528267,
#    'lat': -37.682907,
#    'lon': 145.0704091,
#    'tags': {'addr:housenumber': '5',
#     'addr:street': 'Janefield Drive',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 570482501,
#    'lat': -37.8481054,
#    'lon': 145.0052368,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 570698933,
#    'lat': -37.8591642,
#    'lon': 144.9777767,
#    'tags': {'brand': 'Woolworths Metro',
#     'brand:wikidata': 'Q111772555',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'full_name': 'Woolworths Metro St Kilda West',
#     'name': 'Woolworths Metro',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 570758510,
#    'lat': -37.8685209,
#    'lon': 144.978811,
#    'tags': {'addr:housenumber': '117',
#     'addr:street': 'Acland Street',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-00:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'phone': '+61 3 8347 5870',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 570758511,
#    'lat': -37.8685845,
#    'lon': 144.9806027,
#    'tags': {'addr:housenumber': '181-189',
#     'addr:street': 'Barkly Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 573818021,
#    'lat': -37.7888604,
#    'lon': 144.9895506,
#    'tags': {'addr:housenumber': '292-294',
#     'addr:street': 'Queens Parade',
#     'name': 'McCoppins Food & Wine',
#     'opening_hours': 'Mo-Sa 8:00-21:00; Su 9:00-21:00',
#     'phone': '+61 3 9481 7566',
#     'shop': 'supermarket',
#     'website': 'https://www.mccoppins.com.au/'}},
#   {'type': 'node',
#    'id': 577072359,
#    'lat': -37.9705899,
#    'lon': 145.0687847,
#    'tags': {'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 580722996,
#    'lat': -37.802712,
#    'lon': 144.977554,
#    'tags': {'addr:housenumber': '161-163',
#     'addr:street': 'Brunswick Street',
#     'name': 'KimChi Korean Japanese Grocery',
#     'opening_hours': 'Mo-Sa 10:00-22:00; Su 11:00-21:00',
#     'phone': '+61 3 9416 3438',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 583067216,
#    'lat': -37.8915244,
#    'lon': 145.14381,
#    'tags': {'addr:housenumber': '30-42',
#     'addr:street': 'Centreway',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 591382457,
#    'lat': -37.8175611,
#    'lon': 144.9649673,
#    'tags': {'addr:housenumber': '276',
#     'addr:street': 'Flinders Street',
#     'branch': 'Melbourne Central',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Fr 06:00-24:00; Sa,Su 07:00-24:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 592109271,
#    'lat': -37.9009686,
#    'lon': 145.0910073,
#    'tags': {'addr:housename': 'Centro Oakleigh',
#     'addr:housenumber': '39',
#     'addr:street': 'Hanover Street',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au'}},
#   {'type': 'node',
#    'id': 595501090,
#    'lat': -37.825805,
#    'lon': 144.957017,
#    'tags': {'addr:city': 'Southbank',
#     'addr:housenumber': '46',
#     'addr:postcode': '3006',
#     'addr:state': 'VIC',
#     'addr:street': 'Whiteman Street',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (supermarkets)',
#     'level': '0',
#     'name': 'IGA X-press + Liquor',
#     'opening_hours': 'Mo-Su 08:00-23:00',
#     'shop': 'supermarket',
#     'wheelchair': 'designated'}},
#   {'type': 'node',
#    'id': 595503060,
#    'lat': -37.8164808,
#    'lon': 144.961159,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (Australian supermarket group)',
#     'name': 'IGA',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 596136746,
#    'lat': -38.3453039,
#    'lon': 141.6032498,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 597100017,
#    'lat': -37.6003522,
#    'lon': 144.2249599,
#    'tags': {'name': 'Ballan IGA',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/'}},
#   {'type': 'node',
#    'id': 597205882,
#    'lat': -38.3846768,
#    'lon': 142.2366779,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q3146662',
#     'brand:wikipedia': 'en:IGA (supermarkets)',
#     'name': 'IGA Port Fairy',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 600621370,
#    'lat': -38.2805875,
#    'lon': 144.4916934,
#    'tags': {'name': 'Barwon Heads General Store', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 602490916,
#    'lat': -38.7020259,
#    'lon': 145.8204444,
#    'tags': {'name': 'Venus Bay General Store', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 602904712,
#    'lat': -37.699412,
#    'lon': 144.7778007,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 602905164,
#    'lat': -37.699312,
#    'lon': 144.7785142,
#    'tags': {'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'name': 'ALDI',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 610760024,
#    'lat': -36.3583955,
#    'lon': 146.3165864,
#    'tags': {'addr:city': 'Wangaratta',
#     'addr:housenumber': '1-5',
#     'addr:postcode': '3677',
#     'addr:street': 'Roy Street East',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'brand:wikipedia': 'en:IGA (Australian supermarket group)',
#     'name': 'IGA',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 612554181,
#    'lat': -36.3563765,
#    'lon': 146.327161,
#    'tags': {'addr:city': 'Wangaratta',
#     'addr:housenumber': '13-15',
#     'addr:postcode': '3677',
#     'addr:street': 'Chisholm Street',
#     'brand': 'Aldi',
#     'brand:wikidata': 'Q125054',
#     'brand:wikipedia': 'en:Aldi',
#     'name': 'Aldi',
#     'opening_hours': 'Mo-We 09:00-19:00; Th-Fr 09:00-20:00; Sa 08:30-18:00; Su 09:00-18:00',
#     'shop': 'supermarket',
#     'website': 'https://www.aldi.com.au/'}},
#   {'type': 'node',
#    'id': 612554194,
#    'lat': -36.3599515,
#    'lon': 146.3172286,
#    'tags': {'addr:housenumber': '2-18',
#     'addr:street': 'Ryley Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 613996660,
#    'lat': -37.811152,
#    'lon': 144.965377,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'full_name': 'Woolworths QV',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 616513028,
#    'lat': -37.9865785,
#    'lon': 145.2183528,
#    'tags': {'addr:housenumber': '23-55',
#     'addr:street': 'McCrae Street',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'brand:wikipedia': 'en:Coles Supermarkets',
#     'name': 'Coles',
#     'shop': 'supermarket',
#     'website': 'https://www.coles.com.au/'}},
#   {'type': 'node',
#    'id': 616602030,
#    'lat': -37.84107,
#    'lon': 144.940275,
#    'tags': {'addr:city': 'Port Melboune',
#     'addr:housename': 'Bianca',
#     'addr:housenumber': '120',
#     'addr:postcode': '3207',
#     'addr:street': 'Bay Street',
#     'name': 'About Life',
#     'shop': 'supermarket',
#     'website': 'https://www.aboutlife.com.au/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 617532610,
#    'lat': -38.3730163,
#    'lon': 145.1249803,
#    'tags': {'name': 'IGA', 'operator': 'IGA', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 619027750,
#    'lat': -37.8418505,
#    'lon': 144.9395728,
#    'tags': {'addr:city': 'Port Melbourne',
#     'addr:country': 'AU',
#     'addr:housenumber': '78',
#     'addr:postcode': '3207',
#     'addr:state': 'VIC',
#     'addr:street': 'Bay Street',
#     'name': 'Port Melbourne IGA',
#     'opening_hours': 'Mo-Sa 06:30-24:00, Su 07:30-24:00',
#     'shop': 'supermarket',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 621539656,
#    'lat': -37.8880208,
#    'lon': 144.6072287,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'brand:wikipedia': 'en:Woolworths Supermarkets',
#     'name': 'Woolworths',
#     'shop': 'supermarket',
#     'website': 'https://www.woolworths.com.au/'}},
#   {'type': 'node',
#    'id': 625067911,
#    'lat': -37.8593771,
# ...
#    'id': 10567429114,
#    'lat': -37.9738785,
#    'lon': 145.0163098,
#    'tags': {'addr:city': 'Black Rock',
#     'addr:housenumber': '39-41A',
#     'addr:postcode': '3193',
#     'addr:street': 'Bluff Road',
#     'brand': 'Woolworths Metro',
#     'brand:wikidata': 'Q111772555',
#     'name': 'Woolworths Metro',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket',
#     'source': 'survey'}},
#   {'type': 'node',
#    'id': 10568103910,
#    'lat': -37.7301438,
#    'lon': 144.7430619,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10575386313,
#    'lat': -37.7125819,
#    'lon': 144.7260158,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Su 06:00-23:00',
#     'phone': '+61 433 873 800',
#     'shop': 'supermarket',
#     'website': 'https://www.iga.com.au/'}},
#   {'type': 'node',
#    'id': 10576344803,
#    'lat': -37.8388985,
#    'lon': 144.9902376,
#    'tags': {'addr:housenumber': '114',
#     'addr:postcode': '3141',
#     'addr:state': 'VIC',
#     'addr:street': 'Toorak Road',
#     'addr:suburb': 'South Yarra',
#     'name': 'Gum Tree Good Food',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa 08:00-19:00; Su 09:00-18:30',
#     'payment:apple_pay': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:google_pay': 'yes',
#     'phone': '+61 3 9041 3919',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10590326523,
#    'lat': -37.7634376,
#    'lon': 144.9730183,
#    'tags': {'addr:housenumber': '467',
#     'addr:street': 'Lygon Street',
#     'name': 'Organic Wholefoods',
#     'opening_hours': 'Mo-Fr 08:30-19:00; Sa 08:30-18:00; Su 10:00-17:00',
#     'phone': '+61 3 9384 0288',
#     'shop': 'supermarket',
#     'website': 'https://www.wholefoods.com.au/'}},
#   {'type': 'node',
#    'id': 10590366539,
#    'lat': -37.7631481,
#    'lon': 144.9733325,
#    'tags': {'addr:housenumber': '474',
#     'addr:postcode': '3057',
#     'addr:street': 'Lygon Street',
#     'addr:unit': 'Shop 1',
#     'brand': 'Foodworks',
#     'brand:wikidata': 'Q5465579',
#     'name': 'Foodworks',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'shop': 'supermarket',
#     'website': 'https://foodworks-brunswick-east.myfoodworks.com.au/'}},
#   {'type': 'node',
#    'id': 10614020296,
#    'lat': -37.8100673,
#    'lon': 144.9587799,
#    'tags': {'brand': 'Woolworths Metro',
#     'brand:wikidata': 'Q111772555',
#     'name': 'Woolworths Metro',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10616913654,
#    'lat': -38.3615342,
#    'lon': 144.8904717,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10705702391,
#    'lat': -35.2631991,
#    'lon': 141.1840807,
#    'tags': {'name': 'Friendly Grocer', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10724774963,
#    'lat': -37.8278021,
#    'lon': 145.1943445,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10733530375,
#    'lat': -37.8430583,
#    'lon': 145.0543907,
#    'tags': {'addr:housenumber': '555',
#     'addr:street': 'Burke Road',
#     'name': 'Serendipity',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10743106111,
#    'lat': -37.8112818,
#    'lon': 145.1535054,
#    'tags': {'addr:housenumber': '66-104',
#     'addr:street': 'Springfield Road',
#     'air_conditioning': 'yes',
#     'branch': 'Blackburn',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'level': '1',
#     'name': 'Coles',
#     'opening_hours': 'Mo-Su 06:00-22:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'payment:apple_pay': 'yes',
#     'payment:cash': 'yes',
#     'payment:contactless': 'yes',
#     'payment:debit_cards': 'yes',
#     'payment:google_pay': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:samsung_pay': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+61 3 8863 8200',
#     'shop': 'supermarket',
#     'toilets': 'no',
#     'website': 'https://www.coles.com.au'}},
#   {'type': 'node',
#    'id': 10743106112,
#    'lat': -37.8123394,
#    'lon': 145.1527346,
#    'tags': {'air_conditioning': 'yes',
#     'branch': 'Blackburn North',
#     'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'currency:AUD': 'yes',
#     'level': '1',
#     'name': 'Woolworths',
#     'opening_hours': 'Mo-Su 07:00-22:00',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'payment:american_express': 'yes',
#     'payment:apple_pay': 'yes',
#     'payment:cards': 'yes',
#     'payment:cash': 'yes',
#     'payment:contactless': 'yes',
#     'payment:debit_cards': 'yes',
#     'payment:everyday_pay': 'yes',
#     'payment:google_pay': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:samsung_pay': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+61 3 8841 7627',
#     'shop': 'supermarket',
#     'toilets': 'no',
#     'website': 'https://woolworths.com.au'}},
#   {'type': 'node',
#    'id': 10743106114,
#    'lat': -37.8112786,
#    'lon': 145.1520958,
#    'tags': {'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'name': 'ALDI',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10781714851,
#    'lat': -37.5596167,
#    'lon': 143.8852747,
#    'tags': {'addr:housenumber': '200',
#     'addr:street': 'Victoria Street',
#     'name': 'IGA',
#     'phone': '+61 3 5318 0600',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10841626292,
#    'lat': -37.8821544,
#    'lon': 145.1092559,
#    'tags': {'addr:housenumber': '422',
#     'addr:street': 'Huntingdale Road',
#     'name': "Srini's Ceylon Madura",
#     'phone': '+61 3 9888 2922',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10842028447,
#    'lat': -37.941289,
#    'lon': 145.1683577,
#    'tags': {'addr:housenumber': '754-768',
#     'addr:street': 'Princes Highway',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'brand:wikipedia': 'en:Aldi',
#     'check_date:opening_hours': '2023-05-05',
#     'full_name': 'ALDI Springvale',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Su 08:30-20:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/springvale/754-768-princes-highway',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 10859700605,
#    'lat': -36.8055696,
#    'lon': 144.3572257,
#    'tags': {'addr:housenumber': '939',
#     'addr:postcode': '3551',
#     'addr:street': 'Wellington Road',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'Strathfieldsaye Champions IGA',
#     'opening_hours': 'Mo-Su 07:30-20:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10937779037,
#    'lat': 15.576821,
#    'lon': 120.6844135,
#    'tags': {'name': 'Dalisay', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 10964427614,
#    'lat': -37.9043418,
#    'lon': 144.9982759,
#    'tags': {'addr:housenumber': '12',
#     'addr:street': 'Cochrane Street',
#     'name': 'Dockendorf Grocer',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11088546602,
#    'lat': -37.8428677,
#    'lon': 145.267082,
#    'tags': {'name': 'Bayswater Fresh',
#     'organic': 'only',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11104073377,
#    'lat': -37.8062642,
#    'lon': 144.9617649,
#    'tags': {'level': '0',
#     'name': 'Mr. Dad Super Market',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11142702571,
#    'lat': -37.8196347,
#    'lon': 145.1225176,
#    'tags': {'level': '0',
#     'name': 'Tan Huang Asian Grocer',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 11145701667,
#    'lat': -37.7883914,
#    'lon': 145.149426,
#    'tags': {'level': '0',
#     'name': 'Persian Halal Butchery & Grocery',
#     'opening_hours': 'Mo-Su 09:00-21:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11168824374,
#    'lat': -37.8385464,
#    'lon': 144.9769345,
#    'tags': {'addr:housenumber': '431',
#     'addr:postcode': '3004',
#     'addr:state': 'VIC',
#     'addr:street': 'St Kilda Road',
#     'addr:suburb': 'Melbourne',
#     'name': 'Fawkner Express Grovery Store',
#     'opening_hours': 'Mo-Su 07:15-22:00',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11182312635,
#    'lat': -37.8176845,
#    'lon': 144.9583477,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA X-press',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11203718342,
#    'lat': 23.7192353,
#    'lon': -99.1283085,
#    'tags': {'name': 'suBodega!',
#     'shop': 'supermarket',
#     'website': 'https://www.subodega.mx/'}},
#   {'type': 'node',
#    'id': 11290320670,
#    'lat': -37.6389263,
#    'lon': 144.8804683,
#    'tags': {'name': 'IGA - Greenvale', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11413306247,
#    'lat': -37.8784912,
#    'lon': 145.0923339,
#    'tags': {'addr:housenumber': '695',
#     'addr:street': 'Warrigal Road',
#     'addr:suburb': 'Ashwood',
#     'branch': 'Chadstone Village',
#     'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'check_date': '2023-12-12',
#     'name': 'Coles',
#     'note': 'Approximate location',
#     'opening_hours': 'Mo-Su 06:00-24:00',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'phone': '+61 3 7005 6900',
#     'shop': 'supermarket',
#     'source': 'survey',
#     'start_date': '2023-12-13',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 11418748770,
#    'lat': -37.8072174,
#    'lon': 144.943022,
#    'tags': {'brand': 'Woolworths Metro',
#     'brand:wikidata': 'Q111772555',
#     'name': 'Woolworths Metro',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11422183000,
#    'lat': -37.7026596,
#    'lon': 144.9652668,
#    'tags': {'name': 'Fawkner Mini mart', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11463761081,
#    'lat': -35.9197065,
#    'lon': 145.6493799,
#    'tags': {'addr:housenumber': '39',
#     'addr:postcode': '3644',
#     'addr:state': 'VIC',
#     'addr:street': 'High Street',
#     'addr:suburb': 'Cobram',
#     'name': 'Hong Asian Grocery Shop',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11464615233,
#    'lat': -36.2714207,
#    'lon': 144.5356462,
#    'tags': {'name': 'Lockington Friendly Grocer + Liquor',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11481501508,
#    'lat': -37.7419633,
#    'lon': 144.9652844,
#    'tags': {'name': 'Mahalaxmi Grocery and convenience store',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11502364470,
#    'lat': -37.8318024,
#    'lon': 144.8831375,
#    'tags': {'brand': 'Woolworths',
#     'brand:wikidata': 'Q3249145',
#     'name': 'Woolworths',
#     'operator': 'Woolworths Group',
#     'operator:wikidata': 'Q607272',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11507193094,
#    'lat': -37.7123253,
#    'lon': 142.8392691,
#    'tags': {'name': 'Lake Bolac Licensed Supermarket', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11526476352,
#    'lat': -38.3471445,
#    'lon': 141.6021559,
#    'tags': {'addr:housenumber': '29',
#     'addr:street': 'Henty Street',
#     'branch': 'Portland',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'name': 'ALDI',
#     'opening_hours': 'Mo-Fr 08:30-20:00; Sa, Su 08:30-19:00',
#     'shop': 'supermarket',
#     'website': 'https://store.aldi.com.au/vic/portland/29-henty-street'}},
#   {'type': 'node',
#    'id': 11542169059,
#    'lat': -36.6657147,
#    'lon': 144.3317152,
#    'tags': {'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'Huntly IGA X-press',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11542868206,
#    'lat': -36.3122009,
#    'lon': 145.0499305,
#    'tags': {'operator': 'Ritchies IGA', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11548130121,
#    'lat': -37.7847239,
#    'lon': 144.771428,
#    'tags': {'name': 'NQR', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11571525310,
#    'lat': -37.7565602,
#    'lon': 145.0681732,
#    'tags': {'name': 'Heidelberg Pickles And Pappads', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11586763975,
#    'lat': -38.0949019,
#    'lon': 145.3623668,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11590647855,
#    'lat': -37.6501579,
#    'lon': 143.8853867,
#    'tags': {'brand': 'Foodworks',
#     'brand:wikidata': 'Q5465579',
#     'name': 'Foodworks',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11662256176,
#    'lat': -37.9360111,
#    'lon': 145.0612301,
#    'tags': {'addr:city': 'East Bentleigh',
#     'addr:housenumber': '293',
#     'addr:postcode': '3165',
#     'addr:street': 'Chesterville Road',
#     'branch': 'Local',
#     'brand': 'Foodworks',
#     'brand:wikidata': 'Q5465579',
#     'name': 'Foodworks',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11687951069,
#    'lat': -37.8748714,
#    'lon': 145.2053244,
#    'tags': {'name': 'Big Watermelon', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11693242474,
#    'lat': -37.8383107,
#    'lon': 144.9935719,
#    'tags': {'addr:housenumber': '3 - 7',
#     'addr:street': 'Claremont Street',
#     'name': 'Claremont Supermarket',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11707178513,
#    'lat': -37.8106287,
#    'lon': 145.3431529,
#    'tags': {'name': 'Montrose IGA', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11711718265,
#    'lat': 48.4270968,
#    'lon': -123.335471,
#    'tags': {'name': 'Urban Grocer', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11806575269,
#    'lat': -37.7662487,
#    'lon': 145.0299719,
#    'tags': {'addr:housenumber': '351',
#     'addr:postcode': '3071',
#     'addr:street': 'Darebin Road',
#     'email': 'customerservice@bivihome.com.au',
#     'name': 'Bivihome',
#     'opening_hours': '24/7',
#     'phone': '+61 433 788 159',
#     'shop': 'supermarket',
#     'website': 'https://bivihome.com.au'}},
#   {'type': 'node',
#    'id': 11817971537,
#    'lat': -37.9772167,
#    'lon': 145.2586075,
#    'tags': {'addr:unit': '100A',
#     'brand': 'ALDI',
#     'brand:wikidata': 'Q41171672',
#     'name': 'ALDI',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11834288794,
#    'lat': -37.8386433,
#    'lon': 144.9417288,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11834432297,
#    'lat': -37.7752157,
#    'lon': 144.8866386,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11834437309,
#    'lat': -37.5733957,
#    'lon': 144.8994405,
#    'tags': {'brand': 'Coles',
#     'brand:wikidata': 'Q1108172',
#     'name': 'Coles',
#     'operator': 'Coles Group',
#     'operator:wikidata': 'Q1339055',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11896136770,
#    'lat': -37.917629,
#    'lon': 145.0342877,
#    'tags': {'name': 'Bentleigh Supermarket', 'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 11898349379,
#    'lat': -37.8857274,
#    'lon': 145.0586068,
#    'tags': {'addr:housenumber': '18-30',
#     'addr:postcode': '3163',
#     'addr:state': 'VIC',
#     'addr:street': 'Woorayl Street',
#     'addr:suburb': 'Carnegie',
#     'brand': 'IGA',
#     'brand:wikidata': 'Q5970945',
#     'name': 'IGA',
#     'opening_hours': 'Mo-Su 07:00-23:00',
#     'payment:apple_pay': 'yes',
#     'payment:cards': 'yes',
#     'payment:cash': 'yes',
#     'payment:coins': 'yes',
#     'payment:contactless': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:google_pay': 'yes',
#     'phone': '+61 3 8677 7482',
#     'shop': 'supermarket',
#     'wheelchair': 'yes'}},
#   ...]}

# %%
names = []
latitudes = []
longitudes = []
suburbs = []
postcodes = []
addresses = []

# Store supermarket names and locations as a list
for element in data['elements']:
    # Store names of supermarket
    name = element['tags'].get('name', 'Unnamed Supermarket')
    names.append(name)
    
    # Store coordinates 
    latitudes.append(element['lat'])
    longitudes.append(element['lon'])
    
    # Extract suburb (if available)
    suburb = element['tags'].get('addr:suburb', element['tags'].get('addr:city', 'No Suburb'))
    suburbs.append(suburb)
    
    # Store postcode 
    postcode = element['tags'].get('addr:postcode', 'No Postcode')
    postcodes.append(postcode)
    
    # Store address by combining house number and street
    house_number = element['tags'].get('addr:housenumber', '')
    street = element['tags'].get('addr:street', '')
    address = f"{house_number} {street}".strip()  
    addresses.append(address)

# %%
# Convert lists of supermarkets into a dataframe
supermarkets_df = pd.DataFrame({
    'Supermarket': names,
    'Latitude': latitudes,
    'Longitude': longitudes,
    'Suburb': suburbs,
    'Postcode': postcodes,
    'Address': addresses
})

supermarkets_df[supermarkets_df['Suburb']!='No Suburb']
# Out:
#                   Supermarket   Latitude   Longitude            Suburb  \
# 9                       Coles -37.794199  145.279174           Croydon
# 11                        IGA -36.750813  145.571003             Euroa
# 16             Pepper's Foods  48.460952 -123.296921          Victoria
# 24                 Woolworths -37.822934  145.302038   Bayswater North
# 25                 Woolworths -37.803235  145.310815           Kilysth
# ...                       ...        ...         ...               ...
# 973                     Coles -37.878491  145.092334           Ashwood
# 976   Hong Asian Grocery Shop -35.919706  145.649380            Cobram
# 988                 Foodworks -37.936011  145.061230    East Bentleigh
# 999                       IGA -37.885727  145.058607          Carnegie
# 1005                Foodworks -37.883565  144.689379  Hoppers Crossing
#
#          Postcode                       Address
# 9            3136              5-15 Kent Avenue
# 11           3666              75 Binney Street
# 16        V8N 4G1         3829 Cadboro Bay Road
# 24           3153         17-39 Canterbury Road
# 25           3137  534-542 Mount Dandenong Road
# ...           ...                           ...
# 973   No Postcode             695 Warrigal Road
# 976          3644                39 High Street
# 988          3165         293 Chesterville Road
# 999          3163          18-30 Woorayl Street
# 1005         3029          70 Warringa Crescent
#
# [174 rows x 6 columns]

# %%
# Check entries with suburb names listed.
supermarkets_df[supermarkets_df['Suburb']!='No Suburb']
# Out:
#                   Supermarket   Latitude   Longitude            Suburb  \
# 9                       Coles -37.794199  145.279174           Croydon
# 11                        IGA -36.750813  145.571003             Euroa
# 16             Pepper's Foods  48.460952 -123.296921          Victoria
# 24                 Woolworths -37.822934  145.302038   Bayswater North
# 25                 Woolworths -37.803235  145.310815           Kilysth
# ...                       ...        ...         ...               ...
# 973                     Coles -37.878491  145.092334           Ashwood
# 976   Hong Asian Grocery Shop -35.919706  145.649380            Cobram
# 988                 Foodworks -37.936011  145.061230    East Bentleigh
# 999                       IGA -37.885727  145.058607          Carnegie
# 1005                Foodworks -37.883565  144.689379  Hoppers Crossing
#
#          Postcode                       Address
# 9            3136              5-15 Kent Avenue
# 11           3666              75 Binney Street
# 16        V8N 4G1         3829 Cadboro Bay Road
# 24           3153         17-39 Canterbury Road
# 25           3137  534-542 Mount Dandenong Road
# ...           ...                           ...
# 973   No Postcode             695 Warrigal Road
# 976          3644                39 High Street
# 988          3165         293 Chesterville Road
# 999          3163          18-30 Woorayl Street
# 1005         3029          70 Warringa Crescent
#
# [174 rows x 6 columns]

# %% [markdown]
# * We see that Supermarket Pepper's Foods was labelled as Victoria Suburb with postcode V8N 4G1, how should we approach this?
# * Only 174 out of 1012 entries had a suburb name labelled. Should we remove the suburb column?

# %%
# total supermarkets in Victoria
len(supermarkets_df)
# Out:
# 1012

# %%
# save the DataFrame to a CSV file
supermarkets_df.to_csv('../data/curated/preprocessed_supermarkets.csv', index=False)
