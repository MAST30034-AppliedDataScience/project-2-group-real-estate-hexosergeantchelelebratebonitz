# %% [markdown]
# # 1) Euclidean Distance

# %%
import pandas as pd
import geopandas as gpd

# %%
# display supermarkets' coordinates
supermarkets_df = pd.read_csv('../../data/curated/preprocessed_supermarkets.csv') 
supermarkets_df.head()
# Out:
#   Supermarket   Latitude   Longitude     Suburb     Postcode  \
# 0         IGA -37.277362  144.733861  No Suburb  No Postcode
# 1       Coles -37.791434  145.171842  No Suburb  No Postcode
# 2   Foodworks -37.788987  144.976090  No Suburb  No Postcode
# 3       Coles -37.854786  145.182650  No Suburb  No Postcode
# 4       Coles -37.868257  145.240404  No Suburb  No Postcode
#
#                    Address
# 0                      NaN
# 1       55 Tunstall Square
# 2     799 Nicholson Street
# 3  495-511 Burwood Highway
# 4                      NaN

# %%
# display properties' coordinates
properties_df = pd.read_csv('../../notebooks/Aarav/property_details_with_longlat.csv')
properties_df.head()
# Out:
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb  postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn      3064
# 1              53 Were Street, Brighton VIC 3186     Brighton      3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook      3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert      3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston      3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  \
# 0  $450 Per Week       2.0        1.0      1.0                 House
# 1      $1,490.00       4.0        2.0      2.0                 House
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa
# 3    $800 weekly       5.0        2.0      2.0                 House
# 4  $299 per week       9.0        3.0      4.0             Apartment
#
#                                  structured_features  video_count  \
# 0  [{'category': 'Indoor', 'name': 'Built in ward...          0.0
# 1                                                 []          0.0
# 2  [{'category': 'Outdoor', 'name': 'Secure Parki...          0.0
# 3                                                 []          0.0
# 4  [{'category': 'Indoor', 'name': 'Furnished', '...          0.0
#
#    photo_count              date_listed  days_listed  floor_plans_count  \
# 0         21.0  2024-08-22T16:07:26.000         14.0                0.0
# 1          6.0  2024-06-02T18:11:41.000         95.0                2.0
# 2         17.0  2024-09-03T12:01:18.000          2.0                0.0
# 3          8.0  2024-07-01T12:53:48.000         66.0                0.0
# 4         20.0  2024-07-02T11:24:10.000         65.0                1.0
#
#    virtual_tour                                     nearby_schools   latitude  \
# 0         False  [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897
# 1          True  [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640
# 2          True  [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257
# 3         False  [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918
# 4         False  [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913
#
#     longitude
# 0  144.915516
# 1  144.999904
# 2  144.720254
# 3  145.106110
# 4  145.140409

# %%
# convert supermarkets and properties into GeoDataFrames Point geometry 
supermarkets_gdf = gpd.GeoDataFrame(supermarkets_df, 
                                    geometry=gpd.points_from_xy(supermarkets_df['Longitude'], supermarkets_df['Latitude']), 
                                    crs="EPSG:4326")
properties_gdf = gpd.GeoDataFrame(properties_df, 
                                  geometry=gpd.points_from_xy(properties_df['longitude'], properties_df['latitude']), 
                                  crs="EPSG:4326")

# %%
def closest_supermarket_distance(property_point, supermarkets_gdf):
    '''
    Calculates distance of each houses to the closest supermarket in Victoria.
    
    Parameters:
    - property_point : shapely.geometry.Point = location of each house property
    - supermarkets_gdf : geopandas.GeoDataFrame = supermarkets location in Victoria
    
    Returns:
    - tuple = (minimum Euclidean distance, supermarket geometry)
    '''
    # Calculate the distance between the property and all supermarkets
    distances = supermarkets_gdf.geometry.distance(property_point)
    
    # coordinates of the closest supermarket
    closest_supermarket_geometry = supermarkets_gdf.loc[distances.idxmin()].geometry
    
    # Return the minimum distance and supermarket coordinates
    return distances.min(), closest_supermarket_geometry

# %%
# convert to Metres distance units 
supermarkets_gdf.to_crs(epsg=3857, inplace=True)
properties_gdf.to_crs(epsg=3857, inplace=True)

# %%
# Calculate supermarket's distance (in meters) to each property
properties_gdf['distance_to_closest_supermarket'] = properties_gdf.geometry.apply(
    lambda x: closest_supermarket_distance(x, supermarkets_gdf)[0]
)
properties_gdf['closest_supermarket_geometry'] = properties_gdf.geometry.apply(
    lambda x: closest_supermarket_distance(x, supermarkets_gdf)[1]
)

# %%
properties_gdf.head()
# Out:
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb  postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn      3064
# 1              53 Were Street, Brighton VIC 3186     Brighton      3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook      3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert      3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston      3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  ...  \
# 0  $450 Per Week       2.0        1.0      1.0                 House  ...
# 1      $1,490.00       4.0        2.0      2.0                 House  ...
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa  ...
# 3    $800 weekly       5.0        2.0      2.0                 House  ...
# 4  $299 per week       9.0        3.0      4.0             Apartment  ...
#
#                date_listed  days_listed  floor_plans_count virtual_tour  \
# 0  2024-08-22T16:07:26.000         14.0                0.0        False
# 1  2024-06-02T18:11:41.000         95.0                2.0         True
# 2  2024-09-03T12:01:18.000          2.0                0.0         True
# 3  2024-07-01T12:53:48.000         66.0                0.0        False
# 4  2024-07-02T11:24:10.000         65.0                1.0        False
#
#                                       nearby_schools   latitude   longitude  \
# 0  [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897  144.915516
# 1  [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640  144.999904
# 2  [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257  144.720254
# 3  [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918  145.106110
# 4  [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913  145.140409
#
#                             geometry  distance_to_closest_supermarket  \
# 0   POINT (16131921.46 -4521512.425)                       491.097565
# 1  POINT (16141315.445 -4568926.558)                      1910.765178
# 2  POINT (16110184.994 -4566191.508)                      1381.567610
# 3   POINT (16153138.221 -4553030.95)                      1069.539360
# 4  POINT (16156956.429 -4601332.969)                       612.948151
#
#         closest_supermarket_geometry
# 0  POINT (16131864.843 -4522000.248)
# 1  POINT (16140520.713 -4567188.909)
# 2  POINT (16110905.854 -4565012.911)
# 3  POINT (16153045.358 -4554096.451)
# 4  POINT (16157002.487 -4601944.184)
#
# [5 rows x 23 columns]

# %% [markdown]
# Manual conversion of Supermarket's geometry to Degrees unit (epsg=4326)

# %%
# check that the supermarket is in GeoSeries and in EPSG:3857
supermarket_geo_series = gpd.GeoSeries(properties_gdf['closest_supermarket_geometry'])
supermarket_geo_series.set_crs(epsg=3857, inplace=True)

# Update the properties_gdf with the converted EPSG:4326 geometries
properties_gdf['closest_supermarket_geometry'] = supermarket_geo_series.to_crs(epsg=4326)

# %%
# verify that it is in degrees
properties_gdf['closest_supermarket_geometry']
# Out:
# 0        POINT (144.91501 -37.59237)
# 1        POINT (144.99276 -37.91333)
# 2         POINT (144.72673 -37.8979)
# 3        POINT (145.10528 -37.82048)
# 4        POINT (145.14082 -38.15923)
#                     ...
# 11031    POINT (144.70327 -37.88159)
# 11032    POINT (144.44116 -37.65947)
# 11033    POINT (144.57082 -37.72217)
# 11034    POINT (145.04809 -38.24535)
# 11035    POINT (145.08441 -37.99716)
# Name: closest_supermarket_geometry, Length: 11036, dtype: geometry

# %%
# convert euclidean distance to EPSG:4326 to satisfy API condition later
supermarkets_gdf.to_crs(epsg=4326, inplace=True)
properties_gdf.to_crs(epsg=4326, inplace=True)

# %%
# verify that the location is now in degrees
properties_gdf.head()
# Out:
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb  postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn      3064
# 1              53 Were Street, Brighton VIC 3186     Brighton      3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook      3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert      3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston      3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  ...  \
# 0  $450 Per Week       2.0        1.0      1.0                 House  ...
# 1      $1,490.00       4.0        2.0      2.0                 House  ...
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa  ...
# 3    $800 weekly       5.0        2.0      2.0                 House  ...
# 4  $299 per week       9.0        3.0      4.0             Apartment  ...
#
#                date_listed  days_listed  floor_plans_count virtual_tour  \
# 0  2024-08-22T16:07:26.000         14.0                0.0        False
# 1  2024-06-02T18:11:41.000         95.0                2.0         True
# 2  2024-09-03T12:01:18.000          2.0                0.0         True
# 3  2024-07-01T12:53:48.000         66.0                0.0        False
# 4  2024-07-02T11:24:10.000         65.0                1.0        False
#
#                                       nearby_schools   latitude   longitude  \
# 0  [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897  144.915516
# 1  [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640  144.999904
# 2  [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257  144.720254
# 3  [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918  145.106110
# 4  [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913  145.140409
#
#                       geometry  distance_to_closest_supermarket  \
# 0   POINT (144.91552 -37.5889)                       491.097565
# 1   POINT (144.9999 -37.92564)                      1910.765178
# 2  POINT (144.72025 -37.90626)                      1381.567610
# 3  POINT (145.10611 -37.81292)                      1069.539360
# 4  POINT (145.14041 -38.15491)                       612.948151
#
#    closest_supermarket_geometry
# 0   POINT (144.91501 -37.59237)
# 1   POINT (144.99276 -37.91333)
# 2    POINT (144.72673 -37.8979)
# 3   POINT (145.10528 -37.82048)
# 4   POINT (145.14082 -38.15923)
#
# [5 rows x 23 columns]

# %% [markdown]
# # 2) OpenRouteService API

# %%
import requests
import time

# %%
# Michele's openroute API key
api_key = '5b3ce3597851110001cf62482137f179f8c64044a4f02291f1598019'

# %%
def calculate_driving_distance(lat1, lon1, lat2, lon2, api_key):
    url = 'https://api.openrouteservice.org/v2/directions/driving-car'
    params = {
        'api_key': api_key,
        # properties first as 'start' location then supermarkets for 'end' 
        'start': f'{lon1},{lat1}',  
        'end': f'{lon2},{lat2}'     
    }
    
    try:
        response = requests.get(url, params=params, timeout=10)
        data = response.json()

        if 'features' in data and len(data['features']) > 0:
            # get driving distance (in meters) from API  
            distance = data['features'][0]['properties']['segments'][0]['distance']
            return distance 
        else:
            print(f"Error in response: {data}")
            time.sleep(10)  
            return None
    # error handling
    except Exception as e:
        print(f"Error calculating distance: {e}")
        return None

# %%
# 339 total properties with Euclidean distance greater than 10km
len(properties_gdf[properties_gdf['distance_to_closest_supermarket'] > 10000])
# Out:
# 339

# %% [markdown]
# We only have 2000 API requests per day, so we need to batch the driving distance to those with extremely large Euclidean distance only (greater than 10km).
#
# We assume that properties with Euclidean distance less than 10km has closely similar driving distance. Thus, we only need to process 339 properties' driving distance.

# %% [markdown]
# *Code below takes ~17.5 mins*

# %%
# set threshold for Euclidean distance (in meters)
euclidean_threshold = 10000  

# set driving distance equal to small euclidean distance 
properties_gdf.loc[properties_gdf['distance_to_closest_supermarket'] <= euclidean_threshold, 
                   'driving_distance_to_closest_supermarket'] = properties_gdf['distance_to_closest_supermarket']


# find driving distance for properties with large distance only
large_distance_properties = properties_gdf[properties_gdf['distance_to_closest_supermarket'] > euclidean_threshold]

# find properties with large Euclidean distance only
for idx, row in large_distance_properties.iterrows():
    # retrieve coordinates for each supermarket and property
    property_lon = row['geometry'].x
    property_lat = row['geometry'].y
    supermarket_lon = row['closest_supermarket_geometry'].x
    supermarket_lat = row['closest_supermarket_geometry'].y

    # driving distance using the API
    driving_distance = calculate_driving_distance(property_lat, property_lon, supermarket_lat, supermarket_lon, api_key)
    
    # store results for large driving distance
    properties_gdf.at[idx, 'driving_distance_to_closest_supermarket'] = driving_distance
    
    # Add delay to avoid exceeding the API request limit
    time.sleep(1.5)
# Out:
# Error in response: {'error': {'code': 2010, 'message': 'Could not find routable point within a radius of 350.0 meters of specified coordinate 0: 147.0559844 -36.0480243.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1726822006573}}
# Error in response: {'error': {'code': 2010, 'message': 'Could not find routable point within a radius of 350.0 meters of specified coordinate 0: 145.8182660 -37.5222245.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1726822457667}}
# Error in response: {'error': {'code': 2010, 'message': 'Could not find routable point within a radius of 350.0 meters of specified coordinate 0: 146.2300940 -37.1664244.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1726822745409}}

# %%
# check that euclidean distance is equal to driving distance
properties_gdf[properties_gdf['distance_to_closest_supermarket'] <= 10000].head()
# Out:
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb  postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn      3064
# 1              53 Were Street, Brighton VIC 3186     Brighton      3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook      3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert      3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston      3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  ...  \
# 0  $450 Per Week       2.0        1.0      1.0                 House  ...
# 1      $1,490.00       4.0        2.0      2.0                 House  ...
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa  ...
# 3    $800 weekly       5.0        2.0      2.0                 House  ...
# 4  $299 per week       9.0        3.0      4.0             Apartment  ...
#
#   days_listed  floor_plans_count  virtual_tour  \
# 0        14.0                0.0         False
# 1        95.0                2.0          True
# 2         2.0                0.0          True
# 3        66.0                0.0         False
# 4        65.0                1.0         False
#
#                                       nearby_schools   latitude   longitude  \
# 0  [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897  144.915516
# 1  [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640  144.999904
# 2  [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257  144.720254
# 3  [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918  145.106110
# 4  [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913  145.140409
#
#                       geometry distance_to_closest_supermarket  \
# 0   POINT (144.91552 -37.5889)                      491.097565
# 1   POINT (144.9999 -37.92564)                     1910.765178
# 2  POINT (144.72025 -37.90626)                     1381.567610
# 3  POINT (145.10611 -37.81292)                     1069.539360
# 4  POINT (145.14041 -38.15491)                      612.948151
#
#    closest_supermarket_geometry  driving_distance_to_closest_supermarket
# 0   POINT (144.91501 -37.59237)                               491.097565
# 1   POINT (144.99276 -37.91333)                              1910.765178
# 2    POINT (144.72673 -37.8979)                              1381.567610
# 3   POINT (145.10528 -37.82048)                              1069.539360
# 4   POINT (145.14082 -38.15923)                               612.948151
#
# [5 rows x 24 columns]

# %%
# check that euclidean distance is NOT equal to driving distance
properties_gdf[properties_gdf['distance_to_closest_supermarket'] > 10000].head()
# Out:
#                                                 title  \
# 19  7/36 Clyde Street, Jindabyne NSW 2627 - Apartm...
# 33  1/9 Compton Street, Port Macdonnell SA 5291 - ...
# 46  88 Potoroo Avenue, Thurgoona NSW 2640 - House ...
# 50  156 Hotham Circuit, Thurgoona NSW 2640 - House...
# 53  615 Cape Otway Road, Moriac VIC 3240 - House F...
#
#                                           description  \
# 19  View this 2 bedroom, 1 bathroom rental apartme...
# 33  View this 2 bedroom, 1 bathroom rental apartme...
# 46  View this 4 bedroom, 2 bathroom rental house a...
# 50  View this 2 bedroom, 1 bathroom rental house a...
# 53  View this 3 bedroom, 1 bathroom rental house a...
#
#                                street_address           suburb  postcode  \
# 19        36 Clyde Street, Jindabyne NSW 2627        Jindabyne      2627
# 33  9 Compton Street, Port Macdonnell SA 5291  Port Macdonnell      5291
# 46      88 Potoroo Avenue, Thurgoona NSW 2640        Thurgoona      2640
# 50     156 Hotham Circuit, Thurgoona NSW 2640        Thurgoona      2640
# 53       615 Cape Otway Road, Moriac VIC 3240           Moriac      3240
#
#                        price  bedrooms  bathrooms  parking  \
# 19  $375/week - Summer Lease       2.0        1.0      1.0
# 33                   $210 pw       2.0        1.0      1.0
# 46             $650 per week       4.0        2.0      2.0
# 50             $430 per week       2.0        1.0      1.0
# 53             $670 per week       3.0        1.0      9.0
#
#    primary_property_type  ... days_listed  floor_plans_count  virtual_tour  \
# 19             Apartment  ...         8.0                0.0         False
# 33             Apartment  ...        38.0                0.0         False
# 46                 House  ...         3.0                0.0         False
# 50                 House  ...         3.0                0.0         False
# 53                 House  ...         6.0                1.0         False
#
#                                        nearby_schools   latitude   longitude  \
# 19  [{'address': 'Jindabyne, NSW 2627', 'distance'... -36.415132  148.613347
# 33  [{'address': 'Allendale East, SA 5291', 'dista... -38.055683  140.688524
# 46  [{'address': 'Thurgoona, NSW 2640', 'distance'... -36.063162  147.008277
# 50  [{'address': 'Thurgoona, NSW 2640', 'distance'... -36.045754  146.990595
# 53  [{'address': 'Moriac, VIC 3240', 'distance': 6... -38.243159  144.168297
#
#                        geometry distance_to_closest_supermarket  \
# 19  POINT (148.61335 -36.41513)                    84445.807518
# 33  POINT (140.68852 -38.05568)                   105419.526852
# 46  POINT (147.00828 -36.06316)                    15444.120912
# 50  POINT (146.99059 -36.04575)                    15279.764389
# 53   POINT (144.1683 -38.24316)                    18583.230320
#
#     closest_supermarket_geometry  driving_distance_to_closest_supermarket
# 19   POINT (147.90558 -36.19514)                                 237593.7
# 33   POINT (141.63071 -38.13075)                                 108160.6
# 46    POINT (146.88884 -36.1202)                                  17265.2
# 50    POINT (146.88884 -36.1202)                                  14154.9
# 53   POINT (144.32903 -38.20775)                                  18303.5
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Fill in missing driving distance

# %%
# Check for rows where 'driving_distance_to_closest_supermarket' is NaN
empty_distance_rows = properties_gdf[properties_gdf['driving_distance_to_closest_supermarket'].isna()]

# Print the number of rows where driving distance is empty
print(f"Total properties with missing driving distance: {len(empty_distance_rows)}")
empty_distance_rows
# Out:
# Total properties with missing driving distance: 3
#                                                    title  \
# 2919   Wirlinga NSW 2640 - 4 beds house for Rent, $69...
# 7202   Marysville VIC 3779 - 3 beds house for Rent, $...
# 10516  217 Desmonds Road, Boorolite VIC 3723 - House ...
#
#                                              description  \
# 2919   View this 4 bedroom, 3 bathroom rental house i...
# 7202   View this $2,500/week 3 bedroom, 2 bathroom re...
# 10516  View this 2 bedroom, 1 bathroom rental house a...
#
#                               street_address      suburb  postcode  \
# 2919                       Wirlinga NSW 2640    Wirlinga      2640
# 7202                     Marysville VIC 3779  Marysville      3779
# 10516  217 Desmonds Road, Boorolite VIC 3723   Boorolite      3723
#
#                    price  bedrooms  bathrooms  parking primary_property_type  \
# 2919       $690 per week       4.0        3.0      6.0                 House
# 7202            $2500.00       3.0        2.0      1.0                 House
# 10516  Under Application       2.0        1.0      2.0                 House
#
#        ... days_listed  floor_plans_count  virtual_tour  \
# 2919   ...        28.0                0.0         False
# 7202   ...        17.0                1.0         False
# 10516  ...        90.0                0.0         False
#
#                                           nearby_schools   latitude  \
# 2919   [{'address': 'Thurgoona, NSW 2640', 'distance'... -36.048024
# 7202   [{'address': 'Marysville, VIC 3779', 'distance... -37.522225
# 10516  [{'address': 'Merrijig, VIC 3723', 'distance':... -37.166424
#
#         longitude                     geometry  \
# 2919   147.055984  POINT (147.05598 -36.04802)
# 7202   145.818266  POINT (145.81827 -37.52222)
# 10516  146.230094  POINT (146.23009 -37.16642)
#
#       distance_to_closest_supermarket  closest_supermarket_geometry  \
# 2919                     21096.177328    POINT (146.88884 -36.1202)
# 7202                     35156.685606   POINT (145.69684 -37.75309)
# 10516                    22304.524633   POINT (146.09016 -37.05206)
#
#        driving_distance_to_closest_supermarket
# 2919                                       NaN
# 7202                                       NaN
# 10516                                      NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# Properties with empty driving distances has Euclidean distance greater than 15km, so the properties are assumed to , be in remote areas where the API cannot find a nearby supermarket. Thus we will fill missing values with the Euclidean distance as an approximation for these.

# %%
# Fill missing driving distance with Euclidean distance 
properties_gdf['driving_distance_to_closest_supermarket'].fillna(properties_gdf['distance_to_closest_supermarket'], inplace=True)

# Verify that there's no more missing values
print(properties_gdf['driving_distance_to_closest_supermarket'].isna().sum())
# Out:
# 0

# %%
# save into `data/curated` directory 
properties_gdf.to_csv("../../data/curated/property_details_with_distance_to_closest_supermarkets.csv", index=False)
