# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# display supermarkets' coordinates
supermarkets_df = pd.read_csv('../../data/curated/preprocessed_supermarkets.csv') 
supermarkets_df.head()
# Out:
#   Supermarket   Latitude   Longitude     Suburb     Postcode  \
# 0         IGA -37.277362  144.733861  No Suburb  No Postcode
# 1       Coles -37.791434  145.171842  No Suburb  No Postcode
# 2   Foodworks -37.788987  144.976090  No Suburb  No Postcode
# 3       Coles -37.854786  145.182650  No Suburb  No Postcode
# 4       Coles -37.868257  145.240404  No Suburb  No Postcode
#
#                    Address
# 0                      NaN
# 1       55 Tunstall Square
# 2     799 Nicholson Street
# 3  495-511 Burwood Highway
# 4                      NaN

# %%
# display properties' coordinates
properties_df = pd.read_csv('../../notebooks/Aarav/property_details_with_longlat.csv')
properties_df.head()
# Out:
#                                                title  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1  53 Were Street, Brighton VIC 3186 - House For ...
# 2  43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3  3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4  48 Roberts Street, Frankston VIC 3199 - Studio...
#
#                                          description  \
# 0  View this 2 bedroom, 1 bathroom rental house a...
# 1  View this $1,500/week 4 bedroom, 2 bathroom re...
# 2  View this 3 bedroom, 2 bathroom rental townhou...
# 3  View this 5 bedroom, 2 bathroom rental house a...
# 4  View this 9 bedroom, 3 bathroom rental studio ...
#
#                                   street_address       suburb  postcode  \
# 0  60 Little Windrock Lane, Craigieburn VIC 3064  Craigieburn      3064
# 1              53 Were Street, Brighton VIC 3186     Brighton      3186
# 2           43 Tackle Drive, Point Cook VIC 3030   Point Cook      3030
# 3       3 Rostrevor Parade, Mont Albert VIC 3127  Mont Albert      3127
# 4          48 Roberts Street, Frankston VIC 3199    Frankston      3199
#
#            price  bedrooms  bathrooms  parking primary_property_type  \
# 0  $450 Per Week       2.0        1.0      1.0                 House
# 1      $1,490.00       4.0        2.0      2.0                 House
# 2  $550 per Week       3.0        2.0      2.0       Townhouse/Villa
# 3    $800 weekly       5.0        2.0      2.0                 House
# 4  $299 per week       9.0        3.0      4.0             Apartment
#
#                                  structured_features  video_count  \
# 0  [{'category': 'Indoor', 'name': 'Built in ward...          0.0
# 1                                                 []          0.0
# 2  [{'category': 'Outdoor', 'name': 'Secure Parki...          0.0
# 3                                                 []          0.0
# 4  [{'category': 'Indoor', 'name': 'Furnished', '...          0.0
#
#    photo_count              date_listed  days_listed  floor_plans_count  \
# 0         21.0  2024-08-22T16:07:26.000         14.0                0.0
# 1          6.0  2024-06-02T18:11:41.000         95.0                2.0
# 2         17.0  2024-09-03T12:01:18.000          2.0                0.0
# 3          8.0  2024-07-01T12:53:48.000         66.0                0.0
# 4         20.0  2024-07-02T11:24:10.000         65.0                1.0
#
#    virtual_tour                                     nearby_schools   latitude  \
# 0         False  [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897
# 1          True  [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640
# 2          True  [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257
# 3         False  [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918
# 4         False  [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913
#
#     longitude
# 0  144.915516
# 1  144.999904
# 2  144.720254
# 3  145.106110
# 4  145.140409

# %%
# convert supermarkets and properties into GeoDataFrames Point geometry 
supermarkets_gdf = gpd.GeoDataFrame(supermarkets_df, 
                                    geometry=gpd.points_from_xy(supermarkets_df['Longitude'], supermarkets_df['Latitude']), 
                                    crs="EPSG:4326")
properties_gdf = gpd.GeoDataFrame(properties_df, 
                                  geometry=gpd.points_from_xy(properties_df['longitude'], properties_df['latitude']), 
                                  crs="EPSG:4326")

# %%
supermarkets_gdf
# Out:
#          Supermarket   Latitude   Longitude     Suburb     Postcode  \
# 0                IGA -37.277362  144.733861  No Suburb  No Postcode
# 1              Coles -37.791434  145.171842  No Suburb  No Postcode
# 2          Foodworks -37.788987  144.976090  No Suburb  No Postcode
# 3              Coles -37.854786  145.182650  No Suburb  No Postcode
# 4              Coles -37.868257  145.240404  No Suburb  No Postcode
# ..               ...        ...         ...        ...          ...
# 962        Foodworks -38.197436  146.523759  No Suburb  No Postcode
# 963        Foodworks -37.820479  145.105275  No Suburb  No Postcode
# 964     Morgan's IGA -37.792190  144.789502  No Suburb  No Postcode
# 965           Pantre -37.810497  144.962168  No Suburb  No Postcode
# 966  Hometown Grocer -37.810336  144.963081  No Suburb  No Postcode
#
#                      Address                     geometry
# 0                        NaN  POINT (144.73386 -37.27736)
# 1         55 Tunstall Square  POINT (145.17184 -37.79143)
# 2       799 Nicholson Street  POINT (144.97609 -37.78899)
# 3    495-511 Burwood Highway  POINT (145.18265 -37.85479)
# 4                        NaN   POINT (145.2404 -37.86826)
# ..                       ...                          ...
# 962                      NaN  POINT (146.52376 -38.19744)
# 963                      NaN  POINT (145.10528 -37.82048)
# 964                      NaN   POINT (144.7895 -37.79219)
# 965                      NaN   POINT (144.96217 -37.8105)
# 966                      NaN  POINT (144.96308 -37.81034)
#
# [967 rows x 7 columns]

# %%
def closest_supermarket_distance(property_point, supermarkets_gdf):
    '''
    Calculates distance of each houses to the closest supermarket in Victoria.
    
    Parameters:
    - property_point : shapely.geometry.Point = location of each house property
    - supermarkets_gdf : geopandas.GeoDataFrame = supermarkets location in Victoria
    
    Returns:
    float = least distance from the property to the closest supermarket, measured 
    in meters (CRS units).
    '''
    # Calculate the distance between a property and all supermarkets
    distances = supermarkets_gdf.geometry.distance(property_point)
    # Return the minimum distance (in meters)
    return distances.min()

# %%
# convert to the same metres distance units using CRS 
supermarkets_gdf.to_crs(epsg=3857, inplace=True)
properties_gdf.to_crs(epsg=3857, inplace=True)

# %%
# Michele's openroute API key
api_key = '5b3ce3597851110001cf62482137f179f8c64044a4f02291f1598019'

# %%
# calculate supermarket's distance (in meters) to each property
properties_gdf['distance_to_closest_supermarket'] = properties_gdf.geometry.apply(
    lambda x: closest_supermarket_distance(x, supermarkets_gdf)
)

# %%
properties_gdf
# Out:
#                                                    title  \
# 0      60 Little Windrock Lane, Craigieburn VIC 3064 ...
# 1      53 Were Street, Brighton VIC 3186 - House For ...
# 2      43 Tackle Drive, Point Cook VIC 3030 - Townhou...
# 3      3 Rostrevor Parade, Mont Albert VIC 3127 - Hou...
# 4      48 Roberts Street, Frankston VIC 3199 - Studio...
# ...                                                  ...
# 11031  16 Harris Avenue, Hoppers Crossing VIC 3029 - ...
# 11032  11 Russell Street, Darley VIC 3340 - House For...
# 11033  27 Grazing Rd, Weir Views VIC 3338 - House For...
# 11034  17 Laming Court, Mount Martha VIC 3934 - House...
# 11035  2/110 Chute Street, Mordialloc VIC 3195 - Hous...
#
#                                              description  \
# 0      View this 2 bedroom, 1 bathroom rental house a...
# 1      View this $1,500/week 4 bedroom, 2 bathroom re...
# 2      View this 3 bedroom, 2 bathroom rental townhou...
# 3      View this 5 bedroom, 2 bathroom rental house a...
# 4      View this 9 bedroom, 3 bathroom rental studio ...
# ...                                                  ...
# 11031  View this 3 bedroom, 1 bathroom rental house a...
# 11032  View this 4 bedroom, 2 bathroom rental house a...
# 11033  View this 3 bedroom, 2 bathroom rental house a...
# 11034  View this 4 bedroom, 2 bathroom rental house a...
# 11035  View this 3 bedroom, 1 bathroom rental house a...
#
#                                       street_address            suburb  \
# 0      60 Little Windrock Lane, Craigieburn VIC 3064       Craigieburn
# 1                  53 Were Street, Brighton VIC 3186          Brighton
# 2               43 Tackle Drive, Point Cook VIC 3030        Point Cook
# 3           3 Rostrevor Parade, Mont Albert VIC 3127       Mont Albert
# 4              48 Roberts Street, Frankston VIC 3199         Frankston
# ...                                              ...               ...
# 11031    16 Harris Avenue, Hoppers Crossing VIC 3029  Hoppers Crossing
# 11032             11 Russell Street, Darley VIC 3340            Darley
# 11033             27 Grazing Rd, Weir Views VIC 3338        Weir Views
# 11034         17 Laming Court, Mount Martha VIC 3934      Mount Martha
# 11035          110 Chute Street, Mordialloc VIC 3195        Mordialloc
#
#        postcode             price  bedrooms  bathrooms  parking  \
# 0          3064     $450 Per Week       2.0        1.0      1.0
# 1          3186         $1,490.00       4.0        2.0      2.0
# 2          3030     $550 per Week       3.0        2.0      2.0
# 3          3127       $800 weekly       5.0        2.0      2.0
# 4          3199     $299 per week       9.0        3.0      4.0
# ...         ...               ...       ...        ...      ...
# 11031      3029       $410 weekly       3.0        1.0      1.0
# 11032      3340  $530.00 per week       4.0        2.0      4.0
# 11033      3338     $415 Per Week       3.0        2.0      2.0
# 11034      3934     $700 per week       4.0        2.0      2.0
# 11035      3195     $580 per week       3.0        1.0      1.0
#
#       primary_property_type  ... photo_count              date_listed  \
# 0                     House  ...        21.0  2024-08-22T16:07:26.000
# 1                     House  ...         6.0  2024-06-02T18:11:41.000
# 2           Townhouse/Villa  ...        17.0  2024-09-03T12:01:18.000
# 3                     House  ...         8.0  2024-07-01T12:53:48.000
# 4                 Apartment  ...        20.0  2024-07-02T11:24:10.000
# ...                     ...  ...         ...                      ...
# 11031                 House  ...        18.0  2024-09-03T12:16:29.000
# 11032                 House  ...        15.0  2024-06-26T11:09:37.000
# 11033                 House  ...         8.0  2024-07-26T14:51:48.000
# 11034                 House  ...         6.0  2024-09-02T10:21:37.000
# 11035                 House  ...        14.0  2024-08-12T11:27:32.000
#
#        days_listed floor_plans_count  virtual_tour  \
# 0             14.0               0.0         False
# 1             95.0               2.0          True
# 2              2.0               0.0          True
# 3             66.0               0.0         False
# 4             65.0               1.0         False
# ...            ...               ...           ...
# 11031          2.0               0.0         False
# 11032         71.0               1.0         False
# 11033         41.0               0.0         False
# 11034          3.0               0.0         False
# 11035         24.0               0.0         False
#
#                                           nearby_schools   latitude  \
# 0      [{'address': 'Craigieburn, VIC 3064', 'distanc... -37.588897
# 1      [{'address': 'Brighton, VIC 3186', 'distance':... -37.925640
# 2      [{'address': 'Point Cook, VIC 3030', 'distance... -37.906257
# 3      [{'address': 'Mont Albert, VIC 3127', 'distanc... -37.812918
# 4      [{'address': 'Frankston, VIC 3199', 'distance'... -38.154913
# ...                                                  ...        ...
# 11031  [{'address': 'Hoppers Crossing, VIC 3029', 'di... -37.874458
# 11032  [{'address': 'Darley, VIC 3340', 'distance': 2... -37.657460
# 11033  [{'address': 'Melton, VIC 3338', 'distance': 9... -37.722881
# 11034  [{'address': 'Mount Martha, VIC 3934', 'distan... -38.251174
# 11035  [{'address': 'Mordialloc, VIC 3195', 'distance... -37.999773
#
#         longitude                           geometry  \
# 0      144.915516   POINT (16131921.46 -4521512.425)
# 1      144.999904  POINT (16141315.445 -4568926.558)
# 2      144.720254  POINT (16110184.994 -4566191.508)
# 3      145.106110   POINT (16153138.221 -4553030.95)
# 4      145.140409  POINT (16156956.429 -4601332.969)
# ...           ...                                ...
# 11031  144.698213   POINT (16107731.39 -4561706.059)
# 11032  144.437942  POINT (16078758.199 -4531148.801)
# 11033  144.575340  POINT (16094053.263 -4540351.834)
# 11034  145.044765   POINT (16146309.404 -4614969.25)
# 11035  145.094164  POINT (16151808.409 -4579393.731)
#
#        distance_to_closest_supermarket
# 0                           491.097565
# 1                          1910.765178
# 2                          1381.567610
# 3                          1069.539360
# 4                           612.948151
# ...                                ...
# 11031                      1153.076355
# 11032                       456.578460
# 11033                       513.470356
# 11034                       904.699313
# 11035                      1147.225572
#
# [11036 rows x 22 columns]

# %%
# save into `data/curated` directory 
properties_gdf.to_csv("../../data/curated/property_details_with_distance_to_closest_supermarkets.csv", index=False)
